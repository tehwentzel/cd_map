# %%
import pandas as pd
import topojson as tp
import json
import numpy as np
from Constants import Constants

# %%
state_file = lambda : Constants.data_root + 'state_2018.json'
county_file = lambda : Constants.data_root + 'county_2018.json'
cd_file = lambda : Constants.data_root + 'cd_2018.json'
cd_vote_file = lambda : Constants.data_root + 'cd_voting.xlsx'
cd_education_file = lambda : Constants.data_root + 'cd_education.xlsx'
cd_age_file = lambda : Constants.data_root + 'cd_age.xlsx'
cd_sexpoverty_file = lambda : Constants.data_root + 'cd_sexpoverty.xlsx'
cd_historical_votes_file = lambda : Constants.data_root + 'cd_historical_party_votes.csv'
county_confirmed_covid_file = lambda : Constants.data_root + 'covid_confirmed_usafacts.csv'
county_population_file = lambda : Constants.data_root + 'covid_county_population_usafacts.csv'
county_covid_deaths_file = lambda : Constants.data_root + 'covid_deaths_usafacts.csv'

# %%
def read_topojson(file):
    with open(file) as f:
        jsonfile = json.load(f)
    return jsonfile

def format_geojson(filename, top_key = 'GEOID'):
    topomap = read_topojson(filename)
    print(topomap.keys())
    newmap = []
    for entry in topomap['features']:
        region = {}
        if entry['type'] != 'Feature':
            print(entry['type'])
            continue
        region['coordinates'] = entry['geometry']['coordinates']
        region['geometry_type'] = entry['geometry']['type']
        for k,v in entry['properties'].items():
            region[k] = v
        newmap.append(region)
    return newmap

def merge_maps(files, names):
    maps = {}
    for file, name in zip(files, names):
        maps[name] = format_geojson(file)
    return maps

def save_maps():
    maps = merge_maps([state_file(), county_file(), cd_file()],['state','county','district'])
    with open('merged_borders.json', 'w', encoding='utf-8') as f:
        json.dump(maps, f, ensure_ascii=False)
        
maps = merge_maps([state_file(), county_file(), cd_file()],['state','county','district'])
# Out:
# dict_keys(['type', 'features'])
# dict_keys(['type', 'features'])
# dict_keys(['type', 'features'])

# %%
district_map_df = pd.DataFrame(merge_maps([cd_file()],['district'])['district']).set_index('GEOID')
district_map_df
# Out:
# dict_keys(['type', 'features'])
#                                              coordinates geometry_type  \
# GEOID
# 1710   [[[-87.89799116363989, 42.4938770661944], [-87...       Polygon
# 4706   [[[-87.114976, 36.642413999999995], [-87.11743...       Polygon
# 4806   [[[-97.321371, 32.64374], [-97.327344, 32.6352...       Polygon
# 4807   [[[-95.584796, 29.932987999999998], [-95.59785...       Polygon
# 4826   [[[-97.39267, 33.183509], [-97.39847999999999,...       Polygon
# ...                                                  ...           ...
# 3605   [[[-73.93426954323711, 40.5667651450013], [-73...       Polygon
# 4902   [[[-114.046682520363, 40.1169354028727], [-114...       Polygon
# 3907   [[[-82.06697199999999, 41.478654999999996], [-...       Polygon
# 4505   [[[-82.0484052363051, 35.189667965478], [-82.0...       Polygon
# 5309   [[[-122.33463284888701, 47.406938475222695], [...       Polygon
#
#       STATEFP CD116FP       AFFGEOID LSAD CDSESSN         ALAND      AWATER
# GEOID
# 1710       17      10  5001600US1710   C2     116     777404163    31605644
# 4706       47      06  5001600US4706   C2     116   16770155959   324676580
# 4806       48      06  5001600US4806   C2     116    5564805243   255530191
# 4807       48      07  5001600US4807   C2     116     419784487     3069802
# 4826       48      26  5001600US4826   C2     116    2349987793   191353567
# ...       ...     ...            ...  ...     ...           ...         ...
# 3605       36      05  5001600US3605   C2     116     134550083   184506173
# 4902       49      02  5001600US4902   C2     116  103639513751  2944001576
# 3907       39      07  5001600US3907   C2     116   10009974812    64567382
# 4505       45      05  5001600US4505   C2     116   14260689226   265732852
# 5309       53      09  5001600US5309   C2     116     475212865   104450286
#
# [441 rows x 9 columns]

# %%
def load_cd_data(file):
    try:
        cd_data = pd.read_excel(file,header=[2,3],index_col=0)
    except:
        cd_data = pd.read_excel(file,header=[2,3,4],index_col=0)
    cd_data = cd_data.loc[cd_data.loc[:,'State abbreviation'].dropna().index,:]
    cd_data.columns = cd_data.columns.map(lambda x: '_'.join([k for k in x if 'Unnamed' not in k]))
    cd_data['state_fips'] = cd_data['State abbreviation'].apply(lambda x: Constants.STATE_FIPS.get(x,'00'))
    cd_data['cd_fips'] = cd_data['Congressional district'].apply(lambda x: Constants.CD_FIPS[x] if x in Constants.CD_FIPS else '0' + str(int(x)) if int(x) < 10 else str(int(x)))
    cd_data['GEOID'] = cd_data['state_fips'] + cd_data['cd_fips']
    return cd_data.set_index('GEOID')

load_cd_data(cd_vote_file())
# Out:
#       State abbreviation State name Congressional district  \
# GEOID
# 0101                  AL    Alabama                      1
# 0102                  AL    Alabama                      2
# 0103                  AL    Alabama                      3
# 0104                  AL    Alabama                      4
# 0105                  AL    Alabama                      5
# ...                  ...        ...                    ...
# 5505                  WI  Wisconsin                      5
# 5506                  WI  Wisconsin                      6
# 5507                  WI  Wisconsin                      7
# 5508                  WI  Wisconsin                      8
# 5600                  WY    Wyoming               At-large
#
#        Votes cast for congressional representative for the November 6, 2018 election1  \
# GEOID
# 0101                                            242617.0
# 0102                                            226230.0
# 0103                                            231915.0
# 0104                                            230969.0
# 0105                                            260673.0
# ...                                                  ...
# 5505                                            364288.0
# 5506                                            325065.0
# 5507                                            322840.0
# 5508                                            328774.0
# 5600                                            205275.0
#
#        Citizen voting- age population2_Estimate  \
# GEOID
# 0101                                   544464.0
# 0102                                   516295.0
# 0103                                   543854.0
# 0104                                   515701.0
# 0105                                   551968.0
# ...                                         ...
# 5505                                   558805.0
# 5506                                   556485.0
# 5507                                   552651.0
# 5508                                   556205.0
# 5600                                   433644.0
#
#        Citizen voting- age population2_Margin of error (MOE)  \
# GEOID
# 0101                                              3424.0
# 0102                                              5674.0
# 0103                                              4099.0
# 0104                                              4678.0
# 0105                                              2121.0
# ...                                                  ...
# 5505                                              5239.0
# 5506                                              2532.0
# 5507                                              2556.0
# 5508                                              2262.0
# 5600                                              2221.0
#
#        Voting rate3_Estimate  Voting rate3_Margin of error (MOE) state_fips  \
# GEOID
# 0101               44.560706                            0.280231         01
# 0102               43.817972                            0.481553         01
# 0103               42.642878                            0.321397         01
# 0104               44.787386                            0.406273         01
# 0105               47.226107                            0.181472         01
# ...                      ...                                 ...        ...
# 5505               65.190541                            0.611185         55
# 5506               58.413973                            0.265783         55
# 5507               58.416614                            0.270176         55
# 5508               59.110220                            0.240392         55
# 5600               47.337217                            0.242448         56
#
#       cd_fips
# GEOID
# 0101       01
# 0102       02
# 0103       03
# 0104       04
# 0105       05
# ...       ...
# 5505       05
# 5506       06
# 5507       07
# 5508       08
# 5600       00
#
# [436 rows x 10 columns]

# %%
def merged_cd_demo_data():
    cd_demo_df = None
    for file in [cd_vote_file, cd_education_file, cd_age_file, cd_sexpoverty_file]:
        demo_data = load_cd_data(file())
        if cd_demo_df is None:
            cd_demo_df = demo_data
        else:
            overlap = set(demo_data.columns).intersection(set(cd_demo_df.columns))
            cd_demo_df = cd_demo_df.merge(demo_data.drop(list(overlap),axis=1),on='GEOID',how='inner')
    return cd_demo_df
merged_cd_demo_data().columns
# Out:
# Index(['State abbreviation', 'State name', 'Congressional district',
#        'Votes cast for congressional representative for the November 6, 2018 election1',
#        'Citizen voting- age population2_Estimate',
#        'Citizen voting- age population2_Margin of error (MOE)',
#        'Voting rate3_Estimate', 'Voting rate3_Margin of error (MOE)',
#        'state_fips', 'cd_fips', 'Citizen voting-age population_Estimate',
#        'Citizen voting-age population_Margin of error (MOE)',
#        'Educational attainment_Less than 9th grade_Estimate',
#        'Educational attainment_Less than 9th grade_Margin of error (MOE)',
#        'Educational attainment_Less than 9th grade_Percent of total',
#        'Educational attainment_Less than 9th grade_Percent of total margin of error (MOE)',
#        'Educational attainment_9th to 12 Grade, no diploma_Estimate',
#        'Educational attainment_9th to 12 Grade, no diploma_Margin of error (MOE)',
#        'Educational attainment_9th to 12 Grade, no diploma_Percent of total',
#        'Educational attainment_9th to 12 Grade, no diploma_Percent of total margin of error (MOE)',
#        'Educational attainment_High school graduate_Estimate',
#        'Educational attainment_High school graduate_Margin of error (MOE)',
#        'Educational attainment_High school graduate_Percent of total',
#        'Educational attainment_High school graduate_Percent of total margin of error (MOE)',
#        'Educational attainment_Some college, no degree_Estimate',
#        'Educational attainment_Some college, no degree_Margin of error (MOE)',
#        'Educational attainment_Some college, no degree_Percent of total',
#        'Educational attainment_Some college, no degree_Percent of total margin of error (MOE)',
#        'Educational attainment_Associate's degree_Estimate',
#        'Educational attainment_Associate's degree_Margin of error (MOE)',
#        'Educational attainment_Associate's degree_Percent of total',
#        'Educational attainment_Associate's degree_Percent of total margin of error (MOE)',
#        'Educational attainment_Bachelor's degree_Estimate',
#        'Educational attainment_Bachelor's degree_Margin of error (MOE)',
#        'Educational attainment_Bachelor's degree_Percent of total',
#        'Educational attainment_Bachelor's degree_Percent of total margin of error (MOE)',
#        'Educational attainment_Graduate degree_Estimate',
#        'Educational attainment_Graduate degree_Margin of error (MOE)',
#        'Educational attainment_Graduate degree_Percent of total',
#        'Educational attainment_Graduate degree_Percent of total margin of error (MOE)',
#        'Educational attainment_High school or more_Estimate',
#        'Educational attainment_High school or more_Margin of error (MOE)',
#        'Educational attainment_High school or more_Percent of total',
#        'Educational attainment_High school or more_Percent of total margin of error (MOE)',
#        'Educational attainment_Bachelor's degree or more_Estimate',
#        'Educational attainment_Bachelor's degree or more_Margin of error (MOE)',
#        'Educational attainment_Bachelor's degree or more_Percent of total',
#        'Educational attainment_Bachelor's degree or more_Percent of total margin of error (MOE)',
#        'Age_18-29 years old_Estimate',
#        'Age_18-29 years old_Margin of error (MOE)',
#        'Age_18-29 years old_Percent of total',
#        'Age_18-29 years old_Percent of total margin of error (MOE)',
#        'Age_30-44 years old_Estimate',
#        'Age_30-44 years old_Margin of error (MOE)',
#        'Age_30-44 years old_Percent of total',
#        'Age_30-44 years old_Percent of total margin of error (MOE)',
#        'Age_45-64 years old_Estimate',
#        'Age_45-64 years old_Margin of error (MOE)',
#        'Age_45-64 years old_Percent of total',
#        'Age_45-64 years old_Percent of total margin of error (MOE)',
#        'Age_65 years old and older_Estimate',
#        'Age_65 years old and older_Margin of error (MOE)',
#        'Age_65 years old and older_Percent of total',
#        'Age_65 years old and older_Percent of total margin of error (MOE)',
#        'Sex_Men_Estimate', 'Sex_Men_Margin of error (MOE)',
#        'Sex_Men_Percent of total',
#        'Sex_Men_Percent of total margin of error (MOE)', 'Sex_Women_Estimate',
#        'Sex_Women_Margin of error (MOE)', 'Sex_Women_Percent of total',
#        'Sex_Women_Percent of total margin of error (MOE)',
#        'Poverty_Poverty universe1',
#        'Poverty_Poverty universe margin of error (MOE)',
#        'Poverty_Below poverty level_Estimate',
#        'Poverty_Below poverty level_Margin of error (MOE)',
#        'Poverty_Below poverty level_Percent of total',
#        'Poverty_Below poverty level_Percent of total margin of error (MOE)'],
#       dtype='object')

# %%
def load_2018_votedata():
    drop_cols = ['candidate','writein','version','year','unofficial','mode','runoff']
    vote_data = pd.read_csv(cd_historical_votes_file(), engine='python',dtype = {'party':str})
    vote_data = vote_data[vote_data.year == 2018]
    vote_data = vote_data[~vote_data.unofficial]
    vote_data = vote_data[vote_data['mode'] == 'total']
    vote_data.party = vote_data.party.apply(lambda x : x if x in ['democrat','republican','libertarian'] else 'other')
    vote_data = vote_data.drop(drop_cols, axis=1)
    return vote_data

def to_2digit(num):
    if num > 9:
        return str(num)
    else:
        return '0' + str(num)
    
def cleaned_votedata():
    vote_data = load_2018_votedata()
    votedata_df = []
    for (state_fips,district),v in vote_data.groupby(['state_fips','district']):
        geoid = to_2digit(state_fips) + to_2digit(district)
        district_data = {'GEOID': geoid}
        district_data['totalvotes'] = np.unique(v.totalvotes).mean()
        parties_included = np.unique(v['party'])
        for party in ['democrat','republican','libertarian','other']:
            colname = party + '_' + 'votes'
            if party not in parties_included:
                vcount = 0
            else:
                vcount = v[v.party == party].candidatevotes.sum()
            district_data[colname] = vcount
        votedata_df.append(district_data)

    return pd.DataFrame(votedata_df).set_index('GEOID')   

votedata = cleaned_votedata()
votedata
# Out:
#        totalvotes  democrat_votes  republican_votes  libertarian_votes  \
# GEOID
# 0101     242617.0           89226            153228                  0
# 0102     226230.0           86931            138879                  0
# 0103     231915.0           83996            147770                  0
# 0104     230969.0           46492            184255                  0
# 0105     260673.0          101388            159063                  0
# ...           ...             ...               ...                ...
# 5505     364288.0          138385            225619                  0
# 5506     325065.0          144536            180311                  0
# 5507     322840.0          124307            194061                  0
# 5508     328774.0          119265            209410                  0
# 5600     201245.0           59903            127963               6918
#
#        other_votes
# GEOID
# 0101           163
# 0102           420
# 0103           149
# 0104           222
# 0105           222
# ...            ...
# 5505           284
# 5506           218
# 5507          4472
# 5508            99
# 5600          6461
#
# [419 rows x 5 columns]

# %%
def combine_data():
    district_map_df = pd.DataFrame(merge_maps([cd_file()],['district'])['district']).set_index('GEOID')
    df = district_map_df.merge(merged_cd_demo_data(), on='GEOID',how='left').fillna('null')
    to_keep = list(Constants.CD_KEYS.keys())
    df = df.loc[:,to_keep].rename(Constants.CD_KEYS,axis=1)
    df = df.merge(cleaned_votedata(),on='GEOID',how='left').fillna(0)
    return df
combine_data().to_json(Constants.data_root + 'congression_district_data.json',orient='index')
# Out:
# dict_keys(['type', 'features'])

# %%
county_map_df = pd.DataFrame(format_geojson(county_file())).set_index('GEOID')
county_map_df
# Out:
# dict_keys(['type', 'features'])
#                                              coordinates geometry_type  \
# GEOID
# 37017  [[[-78.90199799999999, 34.835268], [-78.805720...       Polygon
# 37167  [[[-80.29542099999999, 35.502919999999996], [-...       Polygon
# 39153  [[[-81.68495, 41.277145999999995], [-81.68699,...       Polygon
# 42113  [[[-76.81373099999999, 41.590033999999996], [-...       Polygon
# 48459  [[[-95.15211, 32.902640999999996], [-95.15274,...       Polygon
# ...                                                  ...           ...
# 38005  [[[-99.492919, 48.370945999999996], [-99.84661...       Polygon
# 72079  [[[-67.109044, 18.056085], [-67.115765, 18.031...       Polygon
# 31159  [[[-97.368118, 41.046946999999996], [-97.36840...       Polygon
# 37023  [[[-81.94318799999999, 35.960049999999995], [-...       Polygon
# 13261  [[[-84.431214, 32.134057999999996], [-84.43301...       Polygon
#
#       STATEFP COUNTYFP  COUNTYNS        AFFGEOID      NAME LSAD       ALAND  \
# GEOID
# 37017      37      017  01026336  0500000US37017    Bladen   06  2265887723
# 37167      37      167  01025844  0500000US37167    Stanly   06  1023370459
# 39153      39      153  01074088  0500000US39153    Summit   06  1069181981
# 42113      42      113  01213687  0500000US42113  Sullivan   06  1165338428
# 48459      48      459  01384015  0500000US48459    Upshur   06  1509910100
# ...       ...      ...       ...             ...       ...  ...         ...
# 38005      38      005  01034216  0500000US38005    Benson   06  3596569006
# 72079      72      079  01804520  0500000US72079     Lajas   13   155287827
# 31159      31      159  00835901  0500000US31159    Seward   06  1479995670
# 37023      37      023  01008539  0500000US37023     Burke   06  1311146878
# 13261      13      261  00343504  0500000US13261    Sumter   06  1250630094
#
#           AWATER
# GEOID
# 37017   33010866
# 37167   25242751
# 39153   18958267
# 42113    6617028
# 48459   24878888
# ...          ...
# 38005  131708143
# 72079  106643202
# 31159   11542537
# 37023   20719896
# 13261   25227638
#
# [3220 rows x 10 columns]

# %%
def drop_dates(data, start_date, date_interval):
    curr_date = pd.to_datetime(start_date)
    #'/' checks if it's a date column.  Not super robust but works for now since usafacts used m/d/yyy format
    keep_cols = [k for k in data.columns if '/' not in k]
    dates = [k for k in data.columns if '/' in k]
    for d in dates:
        d_date = pd.to_datetime(d)
        if (d_date - curr_date).days == date_interval:
            keep_cols.append(d)
            curr_date = d_date
    return data.loc[:, keep_cols]
    
def clean_usafacts_countyfips(file, start_date = '4/01/20', date_interval = 14):
    countydata = pd.read_csv(file)
    if start_date is not None:
        countydata = drop_dates(countydata, start_date, date_interval)
    newfips = np.zeros((countydata.shape[0],)).astype(str)
    pos = 0
    for idx, row in county_covid.iterrows():
        fips = str(int(row.countyFIPS))
        if len(fips) == 4:
            fips = '0'+fips
        if fips == '0' or fips == '1':
            #statewide unallocated stuff. will probably be dropped since it doesn't show up in the map
            fips = to_2digit(row.stateFIPS) + '000'
        newfips[pos] = fips
        pos += 1
    countydata.index = newfips
    countydata.index.name = "GEOID"
    return countydata
clean_usafacts_countyfips(county_confirmed_covid_file())
# Out:
#        countyFIPS            County Name State  stateFIPS  4/15/20  4/29/20  \
# GEOID
# 01000           0  Statewide Unallocated    AL          1        0        0
# 01001        1001         Autauga County    AL          1       25       42
# 01003        1003         Baldwin County    AL          1       98      173
# 01005        1005         Barbour County    AL          1       13       37
# 01007        1007            Bibb County    AL          1       19       42
# ...           ...                    ...   ...        ...      ...      ...
# 56037       56037      Sweetwater County    WY         56       10       10
# 56039       56039           Teton County    WY         56       59       64
# 56041       56041           Uinta County    WY         56        4        6
# 56043       56043        Washakie County    WY         56        5        5
# 56045       56045          Weston County    WY         56        0        0
#
#        5/13/20  5/27/20  6/10/20
# GEOID
# 01000        0        0        0
# 01001       93      192      295
# 01003      231      281      331
# 01005       69      130      208
# 01007       46       71       89
# ...        ...      ...      ...
# 56037       13       25       35
# 56039       68      100      101
# 56041        7       12       39
# 56043        5       33       39
# 56045        0        1        1
#
# [3195 rows x 9 columns]

# %%
def nondate_cols(df):
    return set([x for x in df.columns if '/' not in x])

def merged_county_data(to_drop = None):
    county_deaths = clean_usafacts_countyfips(county_covid_deaths_file())
    county_cases = clean_usafacts_countyfips(county_confirmed_covid_file())
    county_pop = clean_usafacts_countyfips(county_population_file(), None)
    shared_cols = list(nondate_cols(county_deaths).intersection(nondate_cols(county_pop)))
    county_data = county_pop.merge(county_deaths.drop(shared_cols,axis=1), on='GEOID')
    shared_cols = list(nondate_cols(county_data).intersection(nondate_cols(county_cases)))
    county_data = county_data.merge(county_cases.drop(shared_cols,axis=1),on='GEOID',suffixes = ('_deaths','_cases'))
    if to_drop is not None:
        county_data = county_data.drop(to_drop,axis=1)
    return county_data

county_data = merged_county_data()
county_data
# Out:
#        countyFIPS            County Name State  population  stateFIPS  \
# GEOID
# 01000           0  Statewide Unallocated    AL           0          1
# 01001        1001         Autauga County    AL       55869          1
# 01003        1003         Baldwin County    AL      223234          1
# 01005        1005         Barbour County    AL       24686          1
# 01007        1007            Bibb County    AL       22394          1
# ...           ...                    ...   ...         ...        ...
# 56037       56037      Sweetwater County    WY       42343         56
# 56039       56039           Teton County    WY       23464         56
# 56041       56041           Uinta County    WY       20226         56
# 56043       56043        Washakie County    WY        7805         56
# 56045       56045          Weston County    WY        6927         56
#
#        4/15/20_deaths  4/29/20_deaths  5/13/20_deaths  5/27/20_deaths  \
# GEOID
# 01000               0               0               0               0
# 01001               1               3               3               3
# 01003               0               2               7               9
# 01005               0               1               1               1
# 01007               0               0               1               1
# ...               ...             ...             ...             ...
# 56037               0               0               0               0
# 56039               0               1               1               1
# 56041               0               0               0               0
# 56043               0               0               0               3
# 56045               0               0               0               0
#
#        6/10/20_deaths  4/15/20_cases  4/29/20_cases  5/13/20_cases  \
# GEOID
# 01000               0              0              0              0
# 01001               6             25             42             93
# 01003               9             98            173            231
# 01005               1             13             37             69
# 01007               1             19             42             46
# ...               ...            ...            ...            ...
# 56037               0             10             10             13
# 56039               1             59             64             68
# 56041               0              4              6              7
# 56043               3              5              5              5
# 56045               0              0              0              0
#
#        5/27/20_cases  6/10/20_cases
# GEOID
# 01000              0              0
# 01001            192            295
# 01003            281            331
# 01005            130            208
# 01007             71             89
# ...              ...            ...
# 56037             25             35
# 56039            100            101
# 56041             12             39
# 56043             33             39
# 56045              1              1
#
# [3207 rows x 15 columns]

# %%
def county_vote_data():
    df = pd.read_csv(Constants.data_root + 'election-context-2018.csv')
    df['GEOID'] = df.fips.apply(lambda x: str(x) if len(str(x)) > 4 else '0' + str(x))
    
    for party in ['rep','dem','other']:
        name = party + 'gov'
        newcol = np.zeros((df.shape[0]))
        for i,row in df.loc[:,[name+'16',name+'14']].iterrows():
            newval = row[name+'16']
            if np.isnan(newval):
                newval = row[name+'14']
            newcol[i] = newval
        df[name] = newcol
        
    valid_fields = set(Constants.COUNTY_DEMOGRAPHICS).intersection(set(df.columns))
    if len(set(Constants.COUNTY_DEMOGRAPHICS) - valid_fields) > 0:
        print(set(Constants.COUNTY_DEMOGRAPHICS) - valid_fields)
    df = df.set_index('GEOID').loc[:,list(valid_fields)]
    return df
county_vote_data()
# Out:
#        trump16  demgov  age65andolder_pct  lesscollege_pct  othergov   repgov  \
# GEOID
# 01001    18172  3638.0          13.978456        75.407229       0.0   9427.0
# 01003    72883  8416.0          18.714851        70.452889       0.0  37650.0
# 01005     5454  3651.0          16.528895        87.132213       0.0   3111.0
# 01007     6738  1368.0          14.885699        88.000000       0.0   3525.0
# 01009    22859  2178.0          17.192916        86.950243       0.0  12074.0
# ...        ...     ...                ...              ...       ...      ...
# 56037    12154  3886.0           9.417120        78.628507     796.0   6501.0
# 56039     3921  3573.0          11.837510        46.211584     307.0   3998.0
# 56041     6154  1620.0          10.678218        81.793082     564.0   3251.0
# 56043     2911   498.0          19.650341        78.923920     225.0   2039.0
# 56045     3033   352.0          18.355401        81.193281     369.0   1577.0
#
#        foreignborn_pct  hispanic_pct  clf_unemploy_pct  black_pct  rural_pct  \
# GEOID
# 01001         1.838362      2.572254          5.591657  18.370906  42.002162
# 01003         3.269510      4.366698          6.286843   9.225603  42.279099
# 01005         2.859397      4.309762         12.824738  47.888329  67.789635
# 01007         1.351232      2.223994          7.146827  21.212121  68.352607
# 01009         4.271801      8.727298          5.953833   1.557951  89.951502
# ...                ...           ...               ...        ...        ...
# 56037         5.509685     15.859591          5.072255   0.865840  10.916313
# 56039        11.475048     15.174822          2.123447   0.614419  46.430920
# 56041         3.986981      8.959939          6.390755   0.186665  43.095937
# 56043         3.783978     13.962400          7.441860   0.790325  35.954529
# 56045         4.083624      1.003484          3.610949   0.250871  54.536626
#
#        age29andunder_pct  lesshs_pct  clinton16  female_pct  white_pct  \
# GEOID
# 01001          40.037058   12.417046       5936   51.176225  75.683482
# 01003          35.474412    9.972418      18458   51.194928  83.178788
# 01005          37.664387   26.235928       4871   46.498084  45.885624
# 01007          37.329435   19.301587       1874   46.464646  74.765196
# 01009          37.240053   19.968585       2156   50.485235  87.657701
# ...                  ...         ...        ...         ...        ...
# 56037          44.153352    9.314606       3231   47.824244  79.815674
# 56039          35.569995    4.633570       7314   48.097069  81.200548
# 56041          43.205858   10.361224       1202   49.327526  87.718375
# 56043          34.774279   12.577108        532   51.359119  82.397318
# 56045          33.282230    8.592392        299   47.958188  92.222997
#
#        median_hh_inc  otherpres16  ruralurban_cc      cvap
# GEOID
# 01001        53099.0          865            2.0   40690.0
# 01003        51365.0         3874            3.0  151770.0
# 01005        33956.0          144            6.0   20375.0
# 01007        39776.0          207            1.0   17590.0
# 01009        46212.0          573            1.0   42430.0
# ...              ...          ...            ...       ...
# 56037        68233.0         1745            5.0   30565.0
# 56039        75594.0         1392            7.0   16335.0
# 56041        53323.0         1114            7.0   14355.0
# 56043        46212.0          371            7.0    6135.0
# 56045        55640.0          194            7.0    5565.0
#
# [3114 rows x 20 columns]

# %%
def merge_left(df_list, how = 'inner'):
    df = df_list[0]
    for df2 in df_list[1:]:
        overlap = set(df.columns).intersection(set(df2.columns))
        df = df.merge(df2.drop(list(overlap),axis=1),how=how,on=df.index.name)
    return df

def all_county_data():
    county_map_df = pd.DataFrame(format_geojson(county_file())).set_index('GEOID')
    county_map_df = county_map_df.drop(set(county_map_df.columns) - set(Constants.COUNTY_KEYS.keys()) ,axis=1)
    county_map_df = county_map_df.rename(Constants.COUNTY_KEYS, axis=1)
    county_data = merge_left([county_map_df, 
                              merged_county_data().rename(Constants.COUNTY_KEYS, axis=1),
                              county_vote_data()])
    return county_data.fillna('null')
all_county_data()
# Out:
# dict_keys(['type', 'features'])
#                                              coordinates geometry_type  \
# GEOID
# 37017  [[[-78.90199799999999, 34.835268], [-78.805720...       Polygon
# 37167  [[[-80.29542099999999, 35.502919999999996], [-...       Polygon
# 39153  [[[-81.68495, 41.277145999999995], [-81.68699,...       Polygon
# 42113  [[[-76.81373099999999, 41.590033999999996], [-...       Polygon
# 48459  [[[-95.15211, 32.902640999999996], [-95.15274,...       Polygon
# ...                                                  ...           ...
# 22003  [[[-92.978453, 30.878175], [-92.97917, 30.5983...       Polygon
# 38005  [[[-99.492919, 48.370945999999996], [-99.84661...       Polygon
# 31159  [[[-97.368118, 41.046946999999996], [-97.36840...       Polygon
# 37023  [[[-81.94318799999999, 35.960049999999995], [-...       Polygon
# 13261  [[[-84.431214, 32.134057999999996], [-84.43301...       Polygon
#
#       state_fips county_fips county_name   land_area  water_area state  \
# GEOID
# 37017         37         017      Bladen  2265887723    33010866    NC
# 37167         37         167      Stanly  1023370459    25242751    NC
# 39153         39         153      Summit  1069181981    18958267    OH
# 42113         42         113    Sullivan  1165338428     6617028    PA
# 48459         48         459      Upshur  1509910100    24878888    TX
# ...          ...         ...         ...         ...         ...   ...
# 22003         22         003       Allen  1973083810    10634063    LA
# 38005         38         005      Benson  3596569006   131708143    ND
# 31159         31         159      Seward  1479995670    11542537    NE
# 37023         37         023       Burke  1311146878    20719896    NC
# 13261         13         261      Sumter  1250630094    25227638    GA
#
#        population  4/15/20_deaths  ...  lesshs_pct  clinton16  female_pct  \
# GEOID                              ...
# 37017       32722               0  ...   21.557306       7058   52.513496
# 37167       62806               1  ...   15.258048       7094   50.242534
# 39153      541013              15  ...    9.016560     134256   51.520581
# 42113        6066               0  ...   10.957512        750   47.588067
# 48459       41753               0  ...   16.602730       2380   50.594367
# ...           ...             ...  ...         ...        ...         ...
# 22003       25627               8  ...   20.817761       2106   42.199149
# 38005        6832               0  ...   15.022015        842   48.662158
# 31159       17284               0  ...    7.214503       1875   49.184830
# 37023       90485               4  ...   20.395955      11251   50.507398
# 13261       29524              13  ...   22.241192       5520   52.690698
#
#        white_pct  median_hh_inc  demgov16  otherpres16  ruralurban_cc  \
# GEOID
# 37017  54.240437        30408.0      7227          289            6.0
# 37167  81.516251        44140.0      8163          859            6.0
# 39153  78.243057        51562.0      null        11697            2.0
# 42113  93.525865        44926.0      null           95            8.0
# 48459  80.948008        47724.0      null          424            3.0
# ...          ...            ...       ...          ...            ...
# 22003  71.064444        41801.0      null          272            6.0
# 38005  41.502499        41530.0       817          240            9.0
# 31159  95.336878        61563.0      null          593            2.0
# 37023  82.287106        39759.0     13372         1431            2.0
# 13261  39.906662        33534.0      null          178            6.0
#
#            cvap  othergov16
# GEOID
# 37017   25675.0         189
# 37167   46100.0         601
# 39153  412230.0        null
# 42113    5445.0        null
# 48459   29600.0        null
# ...         ...         ...
# 22003   19415.0        null
# 38005    4465.0          81
# 31159   12965.0        null
# 37023   68740.0         876
# 13261   22895.0        null
#
# [3111 rows x 39 columns]

# %%
def reduce_date_data(date_data, days_per_step = 14):
    dates = sorted(date_data.keys())
    new_dates = {dates[0]: date_data[dates[0]]}
    curr_pos = 0
    for pos,d in enumerate(dates):
        if pos - curr_pos >= days_per_step:
            new_dates[d] = date_data[d]
            curr_pos = pos
    return new_dates

def county_data_to_json(acd, savefile = None):
    new_dict = {}
    for k,v in acd.to_dict(orient='index').items():
        entry = {}
        date_data = {}
        #assumes covid date data is format 'dd/mm/yyy_(deaths|cases)' and nothing else has a /
        for key, val in v.items():
            if '/' not in key:
                entry[key] = val
            else:
                date,data_type = key.split('_')
                if val == 'null':
                    val = 0

                if date not in date_data:
                    date_data[date] = {data_type: int(val)}
                else:
                    ed = date_data[date]
                    ed[data_type] = int(val)
                    date_data[date] = ed
        entry['dates'] = date_data
        new_dict[k] = entry
    if savefile is not None:
        with open(Constants.data_root + savefile, 'w') as f:
            json.dump(new_dict, f)
    return new_dict

county_data_to_json(all_county_data(), 'merged_county_data.json')
# Out:
# dict_keys(['type', 'features'])
# {'37017': {'coordinates': [[[-78.90199799999999, 34.835268],
#     [-78.80572099999999, 34.689202],
#     [-78.868961, 34.484778],
#     [-78.830353, 34.462578],
#     [-78.64837299999999, 34.460868999999995],
#     [-78.44532, 34.3774],
#     [-78.334569, 34.367536],
#     [-78.256085, 34.399468999999996],
#     [-78.176501, 34.465356],
#     [-78.255468, 34.508614],
#     [-78.254441, 34.553595],
#     [-78.374363, 34.700722],
#     [-78.391978, 34.741265],
#     [-78.390748, 34.749463],
#     [-78.494705, 34.856182],
#     [-78.516123, 34.845918999999995],
#     [-78.79959699999999, 34.850857],
#     [-78.90199799999999, 34.835268]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '37',
#   'county_fips': '017',
#   'county_name': 'Bladen',
#   'land_area': 2265887723,
#   'water_area': 33010866,
#   'state': 'NC',
#   'population': 32722,
#   'trump16': 8550,
#   'age65andolder_pct': 18.3839321994543,
#   'lesscollege_pct': 85.1816719594177,
#   'foreignborn_pct': 4.40877691995124,
#   'hispanic_pct': 7.48824519649388,
#   'clf_unemploy_pct': 9.01769020566662,
#   'black_pct': 34.7216578626575,
#   'repgov16': 8272.0,
#   'rural_pct': 91.23330491616942,
#   'age29andunder_pct': 34.64329250595,
#   'lesshs_pct': 21.557306058481498,
#   'clinton16': 7058,
#   'female_pct': 52.5134962558774,
#   'white_pct': 54.240436524061096,
#   'median_hh_inc': 30408.0,
#   'demgov16': 7227.0,
#   'otherpres16': 289,
#   'ruralurban_cc': 6.0,
#   'cvap': 25675.0,
#   'othergov16': 189.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 20},
#    '5/13/20': {'deaths': 1, 'cases': 63},
#    '5/27/20': {'deaths': 2, 'cases': 91},
#    '6/10/20': {'deaths': 2, 'cases': 164}}},
#  '37167': {'coordinates': [[[-80.29542099999999, 35.502919999999996],
#     [-80.49737499999999, 35.202104],
#     [-80.50498499999999, 35.184998],
#     [-80.356982, 35.16494],
#     [-80.27682899999999, 35.195721999999996],
#     [-80.17281899999999, 35.147847],
#     [-80.112644, 35.193881999999995],
#     [-80.07536499999999, 35.143080999999995],
#     [-80.098185, 35.255173],
#     [-80.051225, 35.371537],
#     [-80.10849499999999, 35.459451],
#     [-80.182559, 35.504151],
#     [-80.29542099999999, 35.502919999999996]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '37',
#   'county_fips': '167',
#   'county_name': 'Stanly',
#   'land_area': 1023370459,
#   'water_area': 25242751,
#   'state': 'NC',
#   'population': 62806,
#   'trump16': 21964,
#   'age65andolder_pct': 17.4971126876753,
#   'lesscollege_pct': 83.89534605634479,
#   'foreignborn_pct': 3.0374525655832403,
#   'hispanic_pct': 3.86899851509652,
#   'clf_unemploy_pct': 10.317673980347301,
#   'black_pct': 10.481768685035501,
#   'repgov16': 21054.0,
#   'rural_pct': 67.7131303127837,
#   'age29andunder_pct': 36.825606335588205,
#   'lesshs_pct': 15.258047543884802,
#   'clinton16': 7094,
#   'female_pct': 50.242534235274704,
#   'white_pct': 81.5162514436562,
#   'median_hh_inc': 44140.0,
#   'demgov16': 8163.0,
#   'otherpres16': 859,
#   'ruralurban_cc': 6.0,
#   'cvap': 46100.0,
#   'othergov16': 601.0,
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 17},
#    '4/29/20': {'deaths': 4, 'cases': 28},
#    '5/13/20': {'deaths': 4, 'cases': 30},
#    '5/27/20': {'deaths': 4, 'cases': 54},
#    '6/10/20': {'deaths': 4, 'cases': 124}}},
#  '39153': {'coordinates': [[[-81.68495, 41.277145999999995],
#     [-81.68699, 41.135956],
#     [-81.688491, 40.988589999999995],
#     [-81.647689, 40.988563],
#     [-81.647735, 40.914016],
#     [-81.420418, 40.906504],
#     [-81.393249, 40.988530999999995],
#     [-81.393282, 41.025435],
#     [-81.392534, 41.100435],
#     [-81.39211399999999, 41.135722],
#     [-81.391831, 41.276654],
#     [-81.391694, 41.348272],
#     [-81.45033099999999, 41.349148],
#     [-81.517658, 41.350153999999996],
#     [-81.598052, 41.351157],
#     [-81.565139, 41.277758],
#     [-81.590542, 41.277553999999995],
#     [-81.67051, 41.277255],
#     [-81.68495, 41.277145999999995]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '39',
#   'county_fips': '153',
#   'county_name': 'Summit',
#   'land_area': 1069181981,
#   'water_area': 18958267,
#   'state': 'OH',
#   'population': 541013,
#   'trump16': 112026,
#   'age65andolder_pct': 16.197549928699697,
#   'lesscollege_pct': 69.286277896847,
#   'foreignborn_pct': 4.84361954441678,
#   'hispanic_pct': 1.87856039839519,
#   'clf_unemploy_pct': 7.30614074406096,
#   'black_pct': 14.2430713077145,
#   'repgov16': 'null',
#   'rural_pct': 3.87665864989728,
#   'age29andunder_pct': 37.3135293291858,
#   'lesshs_pct': 9.01655950438779,
#   'clinton16': 134256,
#   'female_pct': 51.5205810422408,
#   'white_pct': 78.2430565304449,
#   'median_hh_inc': 51562.0,
#   'demgov16': 'null',
#   'otherpres16': 11697,
#   'ruralurban_cc': 2.0,
#   'cvap': 412230.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 15, 'cases': 294},
#    '4/29/20': {'deaths': 49, 'cases': 584},
#    '5/13/20': {'deaths': 88, 'cases': 946},
#    '5/27/20': {'deaths': 160, 'cases': 1315},
#    '6/10/20': {'deaths': 187, 'cases': 1621}}},
#  '42113': {'coordinates': [[[-76.81373099999999, 41.590033999999996],
#     [-76.74949699999999, 41.405572],
#     [-76.59253199999999, 41.304331999999995],
#     [-76.447597, 41.275628999999995],
#     [-76.407934, 41.308417999999996],
#     [-76.310133, 41.310199],
#     [-76.2831, 41.376517],
#     [-76.22813099999999, 41.511137],
#     [-76.220139, 41.541284999999995],
#     [-76.81373099999999, 41.590033999999996]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '42',
#   'county_fips': '113',
#   'county_name': 'Sullivan',
#   'land_area': 1165338428,
#   'water_area': 6617028,
#   'state': 'PA',
#   'population': 6066,
#   'trump16': 2291,
#   'age65andolder_pct': 26.9120913995557,
#   'lesscollege_pct': 84.4887172189469,
#   'foreignborn_pct': 1.8724214535068202,
#   'hispanic_pct': 1.7296096477308798,
#   'clf_unemploy_pct': 8.89423076923077,
#   'black_pct': 2.3643287845128502,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 26.372580133291002,
#   'lesshs_pct': 10.9575116893678,
#   'clinton16': 750,
#   'female_pct': 47.5880672802285,
#   'white_pct': 93.52586480482391,
#   'median_hh_inc': 44926.0,
#   'demgov16': 'null',
#   'otherpres16': 95,
#   'ruralurban_cc': 8.0,
#   'cvap': 5445.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 1},
#    '5/13/20': {'deaths': 0, 'cases': 1},
#    '5/27/20': {'deaths': 0, 'cases': 2},
#    '6/10/20': {'deaths': 0, 'cases': 3}}},
#  '48459': {'coordinates': [[[-95.15211, 32.902640999999996],
#     [-95.15274, 32.660948999999995],
#     [-95.15341, 32.570115],
#     [-95.01503699999999, 32.542696],
#     [-95.009992, 32.516478],
#     [-94.986935, 32.537245999999996],
#     [-94.98658499999999, 32.537324],
#     [-94.820223, 32.590648],
#     [-94.745779, 32.667556999999995],
#     [-94.70179, 32.652209],
#     [-94.70214, 32.793088],
#     [-94.67235099999999, 32.834756],
#     [-94.705878, 32.879177],
#     [-94.71994199999999, 32.904502],
#     [-95.15211, 32.902640999999996]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '48',
#   'county_fips': '459',
#   'county_name': 'Upshur',
#   'land_area': 1509910100,
#   'water_area': 24878888,
#   'state': 'TX',
#   'population': 41753,
#   'trump16': 13209,
#   'age65andolder_pct': 16.8135004342971,
#   'lesscollege_pct': 84.21615639985251,
#   'foreignborn_pct': 3.0500062042437,
#   'hispanic_pct': 7.67092691400918,
#   'clf_unemploy_pct': 7.67734044918835,
#   'black_pct': 8.64375232659139,
#   'repgov16': 'null',
#   'rural_pct': 79.2999058739729,
#   'age29andunder_pct': 38.0171237126194,
#   'lesshs_pct': 16.6027296200664,
#   'clinton16': 2380,
#   'female_pct': 50.594366546718,
#   'white_pct': 80.9480084377714,
#   'median_hh_inc': 47724.0,
#   'demgov16': 'null',
#   'otherpres16': 424,
#   'ruralurban_cc': 3.0,
#   'cvap': 29600.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 9},
#    '4/29/20': {'deaths': 0, 'cases': 13},
#    '5/13/20': {'deaths': 0, 'cases': 17},
#    '5/27/20': {'deaths': 0, 'cases': 19},
#    '6/10/20': {'deaths': 0, 'cases': 35}}},
#  '48049': {'coordinates': [[[-99.195871, 32.079235],
#     [-99.20276799999999, 31.467233999999998],
#     [-99.09750799999999, 31.44832],
#     [-99.090622, 31.460926999999998],
#     [-99.041741, 31.490302],
#     [-98.991608, 31.484071],
#     [-98.779951, 31.610735],
#     [-98.76005699999999, 31.687896],
#     [-98.668441, 31.700514],
#     [-98.92440099999999, 32.078018],
#     [-99.118665, 32.079585],
#     [-99.195871, 32.079235]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '48',
#   'county_fips': '049',
#   'county_name': 'Brown',
#   'land_area': 2446120250,
#   'water_area': 32375524,
#   'state': 'TX',
#   'population': 37864,
#   'trump16': 12017,
#   'age65andolder_pct': 19.024647423223897,
#   'lesscollege_pct': 81.47469390938159,
#   'foreignborn_pct': 5.3354422037696105,
#   'hispanic_pct': 21.0017134572295,
#   'clf_unemploy_pct': 4.13974022650202,
#   'black_pct': 4.13602214313958,
#   'repgov16': 'null',
#   'rural_pct': 40.4004618695219,
#   'age29andunder_pct': 37.9148543561355,
#   'lesshs_pct': 14.8639164002184,
#   'clinton16': 1621,
#   'female_pct': 50.5575326215896,
#   'white_pct': 73.1303545538421,
#   'median_hh_inc': 43235.0,
#   'demgov16': 'null',
#   'otherpres16': 388,
#   'ruralurban_cc': 5.0,
#   'cvap': 27820.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 11},
#    '4/29/20': {'deaths': 3, 'cases': 34},
#    '5/13/20': {'deaths': 7, 'cases': 51},
#    '5/27/20': {'deaths': 9, 'cases': 57},
#    '6/10/20': {'deaths': 10, 'cases': 60}}},
#  '45021': {'coordinates': [[[-81.8744102050921, 35.183520599502],
#     [-81.806252, 35.055505],
#     [-81.755083, 34.930279999999996],
#     [-81.711694, 34.912577],
#     [-81.481945, 34.866495],
#     [-81.457257, 34.839279999999995],
#     [-81.492108, 34.948955999999995],
#     [-81.487016, 35.034853],
#     [-81.40887599999999, 35.046324],
#     [-81.3676049106764, 35.16409216120449],
#     [-81.494265, 35.169882],
#     [-81.76813440777389, 35.1797077063839],
#     [-81.8744102050921, 35.183520599502]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '45',
#   'county_fips': '021',
#   'county_name': 'Cherokee',
#   'land_area': 1018732778,
#   'water_area': 11714267,
#   'state': 'SC',
#   'population': 57300,
#   'trump16': 15167,
#   'age65andolder_pct': 15.1490919429932,
#   'lesscollege_pct': 84.03117441547971,
#   'foreignborn_pct': 2.16618687137932,
#   'hispanic_pct': 4.03205743327291,
#   'clf_unemploy_pct': 8.74203144921377,
#   'black_pct': 19.9985783843338,
#   'repgov16': 'null',
#   'rural_pct': 61.049474178743104,
#   'age29andunder_pct': 39.924298965774604,
#   'lesshs_pct': 21.7575920451492,
#   'clinton16': 6092,
#   'female_pct': 51.3185485304048,
#   'white_pct': 73.26296335785621,
#   'median_hh_inc': 35719.0,
#   'demgov16': 'null',
#   'otherpres16': 500,
#   'ruralurban_cc': 4.0,
#   'cvap': 42310.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 8},
#    '4/29/20': {'deaths': 0, 'cases': 15},
#    '5/13/20': {'deaths': 0, 'cases': 22},
#    '5/27/20': {'deaths': 2, 'cases': 32},
#    '6/10/20': {'deaths': 5, 'cases': 76}}},
#  '01043': {'coordinates': [[[-87.109911, 34.299299],
#     [-87.111992, 33.992385],
#     [-87.15103599999999, 33.993224999999995],
#     [-87.091836, 33.890093],
#     [-86.963358, 33.858221],
#     [-86.924387, 33.909222],
#     [-86.793914, 33.952059],
#     [-86.68536499999999, 34.05914],
#     [-86.692061, 34.092653999999996],
#     [-86.601147, 34.11904],
#     [-86.56385, 34.170493],
#     [-86.51892699999999, 34.252320999999995],
#     [-86.45302, 34.259316999999996],
#     [-86.477525, 34.302758],
#     [-86.581936, 34.304694],
#     [-87.11011099999999, 34.313798999999996],
#     [-87.109911, 34.299299]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '01',
#   'county_fips': '043',
#   'county_name': 'Cullman',
#   'land_area': 1903073019,
#   'water_area': 52422496,
#   'state': 'AL',
#   'population': 83768,
#   'trump16': 32989,
#   'age65andolder_pct': 17.751733976093302,
#   'lesscollege_pct': 85.03098201445229,
#   'foreignborn_pct': 2.83339072261302,
#   'hispanic_pct': 4.21319297555217,
#   'clf_unemploy_pct': 6.06475679771515,
#   'black_pct': 1.03669634512273,
#   'repgov16': 'null',
#   'rural_pct': 73.2395592368729,
#   'age29andunder_pct': 36.932461016282204,
#   'lesshs_pct': 17.8435097562275,
#   'clinton16': 3798,
#   'female_pct': 50.56323478774161,
#   'white_pct': 92.4639677308279,
#   'median_hh_inc': 39297.0,
#   'demgov16': 'null',
#   'otherpres16': 1086,
#   'ruralurban_cc': 4.0,
#   'cvap': 61625.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 40},
#    '4/29/20': {'deaths': 0, 'cases': 55},
#    '5/13/20': {'deaths': 0, 'cases': 67},
#    '5/27/20': {'deaths': 0, 'cases': 88},
#    '6/10/20': {'deaths': 1, 'cases': 212}}},
#  '54023': {'coordinates': [[[-79.486873, 39.205960999999995],
#     [-79.487175, 39.194905999999996],
#     [-79.306461, 39.209202999999995],
#     [-79.355468, 39.086507999999995],
#     [-79.298164, 39.073209999999996],
#     [-79.357666, 38.964509],
#     [-79.349867, 38.957509],
#     [-79.13429599999999, 38.81334],
#     [-79.046853, 38.927209999999995],
#     [-79.089655, 39.038208],
#     [-78.97989799999999, 39.237624],
#     [-79.134456, 39.312501],
#     [-79.26239211717609, 39.3262438284674],
#     [-79.283723, 39.30964],
#     [-79.35374999999999, 39.278039],
#     [-79.424413, 39.228170999999996],
#     [-79.486873, 39.205960999999995]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '54',
#   'county_fips': '023',
#   'county_name': 'Grant',
#   'land_area': 1236390677,
#   'water_area': 7545525,
#   'state': 'WV',
#   'population': 11568,
#   'trump16': 4346,
#   'age65andolder_pct': 22.1835174171623,
#   'lesscollege_pct': 85.9901685393258,
#   'foreignborn_pct': 0.0594732370433305,
#   'hispanic_pct': 1.14698385726423,
#   'clf_unemploy_pct': 5.97101449275362,
#   'black_pct': 1.47833474936279,
#   'repgov16': 3203.0,
#   'rural_pct': 78.6797352768702,
#   'age29andunder_pct': 32.4299065420561,
#   'lesshs_pct': 18.258426966292102,
#   'clinton16': 512,
#   'female_pct': 49.804587935429105,
#   'white_pct': 96.7799490229397,
#   'median_hh_inc': 38703.0,
#   'demgov16': 1313.0,
#   'otherpres16': 98,
#   'ruralurban_cc': 7.0,
#   'cvap': 9460.0,
#   'othergov16': 237.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 1},
#    '5/13/20': {'deaths': 0, 'cases': 6},
#    '5/27/20': {'deaths': 0, 'cases': 11},
#    '6/10/20': {'deaths': 0, 'cases': 14}}},
#  '46055': {'coordinates': [[[-102.001068, 44.510926],
#     [-102.007336, 43.99453],
#     [-101.064068, 43.994929],
#     [-101.046786, 43.994969999999995],
#     [-101.046916, 44.168484],
#     [-101.166753, 44.168085],
#     [-101.155188, 44.343146999999995],
#     [-101.154516, 44.689947],
#     [-101.136838, 44.747126],
#     [-101.229495, 44.692287],
#     [-101.361918, 44.687825],
#     [-101.38146, 44.653667],
#     [-101.456072, 44.636202999999995],
#     [-101.531035, 44.567875],
#     [-101.71503799999999, 44.579482999999996],
#     [-101.811198, 44.522372999999995],
#     [-101.889038, 44.538458],
#     [-102.000432, 44.511663],
#     [-102.001068, 44.510926]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '46',
#   'county_fips': '055',
#   'county_name': 'Haakon',
#   'land_area': 4689282658,
#   'water_area': 42449843,
#   'state': 'SD',
#   'population': 1899,
#   'trump16': 936,
#   'age65andolder_pct': 22.527737578388802,
#   'lesscollege_pct': 80.0954328561691,
#   'foreignborn_pct': 0.0,
#   'hispanic_pct': 1.1095031355523401,
#   'clf_unemploy_pct': 2.74949083503055,
#   'black_pct': 0.0,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 32.899179932465,
#   'lesshs_pct': 9.33878663940014,
#   'clinton16': 77,
#   'female_pct': 51.3265798359865,
#   'white_pct': 88.8084901109503,
#   'median_hh_inc': 39554.0,
#   'demgov16': 'null',
#   'otherpres16': 31,
#   'ruralurban_cc': 8.0,
#   'cvap': 1575.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 0},
#    '4/29/20': {'deaths': 0, 'cases': 0},
#    '5/13/20': {'deaths': 0, 'cases': 0},
#    '5/27/20': {'deaths': 0, 'cases': 0},
#    '6/10/20': {'deaths': 0, 'cases': 0}}},
#  '55061': {'coordinates': [[[-87.7613076788851, 44.6536977497349],
#     [-87.766026, 44.327183999999995],
#     [-87.5433267854761, 44.3275128561299],
#     [-87.498662, 44.460685999999995],
#     [-87.446963, 44.586273999999996],
#     [-87.401629, 44.631191],
#     [-87.3754915502194, 44.675512109805],
#     [-87.73757086086628, 44.6770118161559],
#     [-87.748409, 44.667122],
#     [-87.7613076788851, 44.6536977497349]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '55',
#   'county_fips': '061',
#   'county_name': 'Kewaunee',
#   'land_area': 886951858,
#   'water_area': 1921336271,
#   'state': 'WI',
#   'population': 20434,
#   'trump16': 6616,
#   'age65andolder_pct': 18.622611075810198,
#   'lesscollege_pct': 83.0995647066952,
#   'foreignborn_pct': 1.93069064959187,
#   'hispanic_pct': 2.5025661078254102,
#   'clf_unemploy_pct': 4.64453232778442,
#   'black_pct': 0.361699007771641,
#   'repgov16': 'null',
#   'rural_pct': 72.33401380383009,
#   'age29andunder_pct': 33.8579598220832,
#   'lesshs_pct': 7.938920748980861,
#   'clinton16': 3623,
#   'female_pct': 49.2057285302312,
#   'white_pct': 95.2734737768219,
#   'median_hh_inc': 58152.0,
#   'demgov16': 'null',
#   'otherpres16': 519,
#   'ruralurban_cc': 2.0,
#   'cvap': 15720.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 5},
#    '4/29/20': {'deaths': 1, 'cases': 13},
#    '5/13/20': {'deaths': 1, 'cases': 29},
#    '5/27/20': {'deaths': 1, 'cases': 33},
#    '6/10/20': {'deaths': 1, 'cases': 37}}},
#  '18049': {'coordinates': [[[-86.467046, 41.171442],
#     [-86.468509, 40.909889],
#     [-86.169012, 40.909836],
#     [-86.168459, 40.996097],
#     [-85.94643599999999, 40.999195],
#     [-85.945561, 41.042876],
#     [-86.07593899999999, 41.084877999999996],
#     [-86.077551, 41.172868],
#     [-86.467046, 41.171442]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '18',
#   'county_fips': '049',
#   'county_name': 'Fulton',
#   'land_area': 954146352,
#   'water_area': 7426335,
#   'state': 'IN',
#   'population': 19974,
#   'trump16': 6010,
#   'age65andolder_pct': 17.670977856163002,
#   'lesscollege_pct': 86.2802484117353,
#   'foreignborn_pct': 2.8806584362139906,
#   'hispanic_pct': 4.86968449931413,
#   'clf_unemploy_pct': 5.97014925373134,
#   'black_pct': 0.9014305310601608,
#   'repgov16': 5142.0,
#   'rural_pct': 64.9212900748704,
#   'age29andunder_pct': 36.890064667842395,
#   'lesshs_pct': 15.140266971232801,
#   'clinton16': 1960,
#   'female_pct': 50.5731922398589,
#   'white_pct': 92.445620223398,
#   'median_hh_inc': 46310.0,
#   'demgov16': 2977.0,
#   'otherpres16': 404,
#   'ruralurban_cc': 7.0,
#   'cvap': 15130.0,
#   'othergov16': 291.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 3},
#    '4/29/20': {'deaths': 0, 'cases': 26},
#    '5/13/20': {'deaths': 1, 'cases': 37},
#    '5/27/20': {'deaths': 1, 'cases': 47},
#    '6/10/20': {'deaths': 1, 'cases': 51}}},
#  '19083': {'coordinates': [[[-93.49948499999999, 42.557700000000004],
#     [-93.46263499999999, 42.470802],
#     [-93.463043, 42.209302],
#     [-93.23172199999999, 42.208886],
#     [-93.001674, 42.209267],
#     [-93.00290199999999, 42.470638],
#     [-93.027, 42.55681],
#     [-93.49948499999999, 42.557700000000004]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '19',
#   'county_fips': '083',
#   'county_name': 'Hardin',
#   'land_area': 1474505075,
#   'water_area': 1776735,
#   'state': 'IA',
#   'population': 16846,
#   'trump16': 5254,
#   'age65andolder_pct': 20.9593627337797,
#   'lesscollege_pct': 79.60972382999829,
#   'foreignborn_pct': 2.54560147771877,
#   'hispanic_pct': 4.034864927268529,
#   'clf_unemploy_pct': 3.4313164817568302,
#   'black_pct': 1.1948741630108501,
#   'repgov16': 'null',
#   'rural_pct': 71.08474962929171,
#   'age29andunder_pct': 34.963057030708796,
#   'lesshs_pct': 8.30990573838267,
#   'clinton16': 2787,
#   'female_pct': 50.0808127453244,
#   'white_pct': 92.68644654814129,
#   'median_hh_inc': 51821.0,
#   'demgov16': 'null',
#   'otherpres16': 492,
#   'ruralurban_cc': 6.0,
#   'cvap': 13230.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 7},
#    '5/13/20': {'deaths': 0, 'cases': 12},
#    '5/27/20': {'deaths': 0, 'cases': 15},
#    '6/10/20': {'deaths': 0, 'cases': 36}}},
#  '20133': {'coordinates': [[[-95.525499, 37.732759],
#     [-95.52556, 37.383979],
#     [-95.52113, 37.38399],
#     [-95.088189, 37.383837],
#     [-95.08801199999999, 37.674519],
#     [-95.088082, 37.732476],
#     [-95.525499, 37.732759]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '20',
#   'county_fips': '133',
#   'county_name': 'Neosho',
#   'land_area': 1480111173,
#   'water_area': 16369480,
#   'state': 'KS',
#   'population': 16007,
#   'trump16': 4431,
#   'age65andolder_pct': 18.1562538207605,
#   'lesscollege_pct': 81.1221183223776,
#   'foreignborn_pct': 1.31434160655337,
#   'hispanic_pct': 4.9578188042548,
#   'clf_unemploy_pct': 3.4414459024511004,
#   'black_pct': 0.7396992297346858,
#   'repgov16': 'null',
#   'rural_pct': 45.13687015503879,
#   'age29andunder_pct': 39.6992297346864,
#   'lesshs_pct': 8.61957226182761,
#   'clinton16': 1501,
#   'female_pct': 51.302115173004,
#   'white_pct': 90.6712312018584,
#   'median_hh_inc': 43867.0,
#   'demgov16': 'null',
#   'otherpres16': 382,
#   'ruralurban_cc': 7.0,
#   'cvap': 12100.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 2},
#    '4/29/20': {'deaths': 0, 'cases': 2},
#    '5/13/20': {'deaths': 0, 'cases': 2},
#    '5/27/20': {'deaths': 0, 'cases': 2},
#    '6/10/20': {'deaths': 0, 'cases': 4}}},
#  '31133': {'coordinates': [[[-96.463667, 40.262173],
#     [-96.4637120767748, 40.000958572554495],
#     [-96.2392078784111, 40.0006910427544],
#     [-96.239172, 40.000690999999996],
#     [-96.154365, 40.000495],
#     [-96.02409, 40.000719],
#     [-96.0106788179345, 40.000704665772005],
#     [-96.010176, 40.261482],
#     [-96.06673599999999, 40.262038],
#     [-96.463667, 40.262173]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '31',
#   'county_fips': '133',
#   'county_name': 'Pawnee',
#   'land_area': 1116478182,
#   'water_area': 4852361,
#   'state': 'NE',
#   'population': 2613,
#   'trump16': 974,
#   'age65andolder_pct': 26.1595547309833,
#   'lesscollege_pct': 83.82956878850099,
#   'foreignborn_pct': 0.8905380333951759,
#   'hispanic_pct': 1.85528756957328,
#   'clf_unemploy_pct': 3.0375699440447597,
#   'black_pct': 0.0,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 31.1688311688312,
#   'lesshs_pct': 9.29158110882957,
#   'clinton16': 279,
#   'female_pct': 50.315398886827495,
#   'white_pct': 95.5473098330241,
#   'median_hh_inc': 40139.0,
#   'demgov16': 'null',
#   'otherpres16': 74,
#   'ruralurban_cc': 9.0,
#   'cvap': 2120.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 0},
#    '4/29/20': {'deaths': 0, 'cases': 0},
#    '5/13/20': {'deaths': 0, 'cases': 0},
#    '5/27/20': {'deaths': 0, 'cases': 0},
#    '6/10/20': {'deaths': 0, 'cases': 0}}},
#  '01059': {'coordinates': [[[-88.15490218400869, 34.46303430044],
#     [-88.1732617345949, 34.3210395343343],
#     [-87.634725, 34.306996999999996],
#     [-87.52972199999999, 34.304598],
#     [-87.52966699999999, 34.567081],
#     [-88.13955944124739, 34.5816967458839],
#     [-88.15490218400869, 34.46303430044]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '01',
#   'county_fips': '059',
#   'county_name': 'Franklin',
#   'land_area': 1641841406,
#   'water_area': 32643981,
#   'state': 'AL',
#   'population': 31362,
#   'trump16': 9466,
#   'age65andolder_pct': 16.0358534190606,
#   'lesscollege_pct': 87.60990061162079,
#   'foreignborn_pct': 8.884173185950019,
#   'hispanic_pct': 16.016849840053197,
#   'clf_unemploy_pct': 9.71294324939432,
#   'black_pct': 4.06043138124347,
#   'repgov16': 'null',
#   'rural_pct': 70.3665152662125,
#   'age29andunder_pct': 39.460931808824,
#   'lesshs_pct': 24.3310397553517,
#   'clinton16': 2197,
#   'female_pct': 50.739555949703906,
#   'white_pct': 78.0730370886517,
#   'median_hh_inc': 36138.0,
#   'demgov16': 'null',
#   'otherpres16': 377,
#   'ruralurban_cc': 6.0,
#   'cvap': 21935.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 17},
#    '4/29/20': {'deaths': 0, 'cases': 45},
#    '5/13/20': {'deaths': 3, 'cases': 270},
#    '5/27/20': {'deaths': 6, 'cases': 498},
#    '6/10/20': {'deaths': 10, 'cases': 634}}},
#  '29175': {'coordinates': [[[-92.692149, 39.610265],
#     [-92.697228, 39.597699],
#     [-92.70736699999999, 39.321614],
#     [-92.430229, 39.248795],
#     [-92.314471, 39.246454],
#     [-92.310028, 39.347795],
#     [-92.300871, 39.605348],
#     [-92.692149, 39.610265]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '29',
#   'county_fips': '175',
#   'county_name': 'Randolph',
#   'land_area': 1250217892,
#   'water_area': 13254191,
#   'state': 'MO',
#   'population': 24748,
#   'trump16': 7529,
#   'age65andolder_pct': 15.589490052230802,
#   'lesscollege_pct': 85.6061047358304,
#   'foreignborn_pct': 0.9568996451497149,
#   'hispanic_pct': 1.9137992902994299,
#   'clf_unemploy_pct': 7.461832061068701,
#   'black_pct': 5.03169730074558,
#   'repgov16': 6505.0,
#   'rural_pct': 45.175887306209205,
#   'age29andunder_pct': 38.5072365535664,
#   'lesshs_pct': 13.555076600454399,
#   'clinton16': 2283,
#   'female_pct': 47.549938200231296,
#   'white_pct': 89.2149435827918,
#   'median_hh_inc': 40638.0,
#   'demgov16': 3561.0,
#   'otherpres16': 497,
#   'ruralurban_cc': 6.0,
#   'cvap': 19350.0,
#   'othergov16': 298.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 8},
#    '4/29/20': {'deaths': 0, 'cases': 8},
#    '5/13/20': {'deaths': 0, 'cases': 8},
#    '5/27/20': {'deaths': 0, 'cases': 9},
#    '6/10/20': {'deaths': 0, 'cases': 10}}},
#  '35028': {'coordinates': [[[-106.248161, 35.966327],
#     [-106.399713, 35.960094999999995],
#     [-106.418778, 35.819986],
#     [-106.250499, 35.755818],
#     [-106.171852, 35.82776],
#     [-106.248257, 35.839178],
#     [-106.245649, 35.930741999999995],
#     [-106.248161, 35.966327]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '35',
#   'county_fips': '028',
#   'county_name': 'Los Alamos',
#   'land_area': 282827023,
#   'water_area': 224479,
#   'state': 'NM',
#   'population': 19369,
#   'trump16': 3359,
#   'age65andolder_pct': 17.077395920648197,
#   'lesscollege_pct': 35.4088050314465,
#   'foreignborn_pct': 9.76809164571109,
#   'hispanic_pct': 16.7756356524169,
#   'clf_unemploy_pct': 2.6418362927674304,
#   'black_pct': 0.530874545962559,
#   'repgov16': 'null',
#   'rural_pct': 11.242339832869101,
#   'age29andunder_pct': 33.0651019837944,
#   'lesshs_pct': 2.81446540880503,
#   'clinton16': 5562,
#   'female_pct': 48.6616373288628,
#   'white_pct': 73.55685945794909,
#   'median_hh_inc': 105902.0,
#   'demgov16': 'null',
#   'otherpres16': 1964,
#   'ruralurban_cc': 6.0,
#   'cvap': 13075.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 5},
#    '4/29/20': {'deaths': 0, 'cases': 6},
#    '5/13/20': {'deaths': 0, 'cases': 6},
#    '5/27/20': {'deaths': 0, 'cases': 6},
#    '6/10/20': {'deaths': 0, 'cases': 6}}},
#  '37105': {'coordinates': [[[-79.350073, 35.518001999999996],
#     [-79.359765, 35.469674999999995],
#     [-79.27356499999999, 35.353369],
#     [-79.183556, 35.307161],
#     [-78.96964, 35.521668999999996],
#     [-79.11709599999999, 35.628164],
#     [-79.244663, 35.569116],
#     [-79.350073, 35.518001999999996]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '37',
#   'county_fips': '105',
#   'county_name': 'Lee',
#   'land_area': 660607408,
#   'water_area': 10725289,
#   'state': 'NC',
#   'population': 61779,
#   'trump16': 13712,
#   'age65andolder_pct': 15.1192475646624,
#   'lesscollege_pct': 79.1787965470977,
#   'foreignborn_pct': 11.202552905609698,
#   'hispanic_pct': 19.1770238495129,
#   'clf_unemploy_pct': 9.360794461151132,
#   'black_pct': 18.9721195834733,
#   'repgov16': 13017.0,
#   'rural_pct': 42.7643175612622,
#   'age29andunder_pct': 39.9445750755794,
#   'lesshs_pct': 19.0491861377617,
#   'clinton16': 10469,
#   'female_pct': 51.2882096069869,
#   'white_pct': 58.3590863285186,
#   'median_hh_inc': 46402.0,
#   'demgov16': 11369.0,
#   'otherpres16': 903,
#   'ruralurban_cc': 4.0,
#   'cvap': 40065.0,
#   'othergov16': 544.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 16},
#    '4/29/20': {'deaths': 0, 'cases': 142},
#    '5/13/20': {'deaths': 2, 'cases': 285},
#    '5/27/20': {'deaths': 3, 'cases': 376},
#    '6/10/20': {'deaths': 4, 'cases': 554}}},
#  '39137': {'coordinates': [[[-84.399486, 40.990314999999995],
#     [-84.39840699999999, 40.903265],
#     [-84.340531, 40.859099],
#     [-84.109586, 40.860994],
#     [-84.109516, 40.90473],
#     [-83.880423, 40.920429],
#     [-83.881149, 41.167823999999996],
#     [-84.228222, 41.165862],
#     [-84.341602, 41.165524],
#     [-84.341911, 40.990691999999996],
#     [-84.399486, 40.990314999999995]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '39',
#   'county_fips': '137',
#   'county_name': 'Putnam',
#   'land_area': 1249783590,
#   'water_area': 4544874,
#   'state': 'OH',
#   'population': 33861,
#   'trump16': 14961,
#   'age65andolder_pct': 15.5733380232149,
#   'lesscollege_pct': 80.610253681036,
#   'foreignborn_pct': 0.835385156524798,
#   'hispanic_pct': 5.9004572634541,
#   'clf_unemploy_pct': 2.86105782406139,
#   'black_pct': 0.296048774768437,
#   'repgov16': 'null',
#   'rural_pct': 84.6604249398533,
#   'age29andunder_pct': 39.1018876773361,
#   'lesshs_pct': 7.14475784992017,
#   'clinton16': 2922,
#   'female_pct': 50.0967288075976,
#   'white_pct': 92.7951694219721,
#   'median_hh_inc': 60245.0,
#   'demgov16': 'null',
#   'otherpres16': 884,
#   'ruralurban_cc': 6.0,
#   'cvap': 25255.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 4},
#    '4/29/20': {'deaths': 6, 'cases': 64},
#    '5/13/20': {'deaths': 13, 'cases': 77},
#    '5/27/20': {'deaths': 14, 'cases': 87},
#    '6/10/20': {'deaths': 14, 'cases': 99}}},
#  '45039': {'coordinates': [[[-81.42270599999999, 34.572029],
#     [-81.427545, 34.529482],
#     [-81.42324099999999, 34.494378999999995],
#     [-81.342297, 34.266928],
#     [-81.31691099999999, 34.239458],
#     [-81.178293, 34.174552],
#     [-81.181196, 34.220285],
#     [-81.095863, 34.213871999999995],
#     [-80.825921, 34.26876],
#     [-80.769926, 34.377111],
#     [-80.879227, 34.457775999999996],
#     [-80.89872199999999, 34.486694],
#     [-80.87749099999999, 34.543146],
#     [-81.42270599999999, 34.572029]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '45',
#   'county_fips': '039',
#   'county_name': 'Fairfield',
#   'land_area': 1777452219,
#   'water_area': 61132193,
#   'state': 'SC',
#   'population': 22347,
#   'trump16': 4027,
#   'age65andolder_pct': 17.8545059717698,
#   'lesscollege_pct': 82.6409135082605,
#   'foreignborn_pct': 1.9022801302931598,
#   'hispanic_pct': 1.9413680781759,
#   'clf_unemploy_pct': 10.807252101691502,
#   'black_pct': 56.5732899022801,
#   'repgov16': 'null',
#   'rural_pct': 78.3144097512105,
#   'age29andunder_pct': 33.8110749185668,
#   'lesshs_pct': 17.8692905733722,
#   'clinton16': 6945,
#   'female_pct': 52.2084690553746,
#   'white_pct': 37.4636264929425,
#   'median_hh_inc': 33798.0,
#   'demgov16': 'null',
#   'otherpres16': 295,
#   'ruralurban_cc': 2.0,
#   'cvap': 18075.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 24},
#    '4/29/20': {'deaths': 2, 'cases': 34},
#    '5/13/20': {'deaths': 5, 'cases': 83},
#    '5/27/20': {'deaths': 13, 'cases': 163},
#    '6/10/20': {'deaths': 19, 'cases': 219}}},
#  '48021': {'coordinates': [[[-97.36953899999999, 30.419563],
#     [-97.400089, 30.367905999999998],
#     [-97.491254, 30.21211],
#     [-97.49135, 30.21193],
#     [-97.64936999999999, 30.067943999999997],
#     [-97.315823, 29.786541],
#     [-97.19423499999999, 29.896776],
#     [-97.024461, 30.051434999999998],
#     [-97.081834, 30.259356999999998],
#     [-97.158811, 30.310695],
#     [-97.199578, 30.337833],
#     [-97.251707, 30.362848],
#     [-97.334463, 30.402842999999997],
#     [-97.36953899999999, 30.419563]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '48',
#   'county_fips': '021',
#   'county_name': 'Bastrop',
#   'land_area': 2300370292,
#   'water_area': 19079348,
#   'state': 'TX',
#   'population': 88723,
#   'trump16': 16328,
#   'age65andolder_pct': 13.408527706103301,
#   'lesscollege_pct': 81.6378462784107,
#   'foreignborn_pct': 10.865288812814601,
#   'hispanic_pct': 35.1633753161485,
#   'clf_unemploy_pct': 8.586255259467041,
#   'black_pct': 7.80216130598064,
#   'repgov16': 'null',
#   'rural_pct': 63.852449070391394,
#   'age29andunder_pct': 39.4016810157627,
#   'lesshs_pct': 19.424363348948397,
#   'clinton16': 10569,
#   'female_pct': 49.082850062591,
#   'white_pct': 54.4426845157499,
#   'median_hh_inc': 55808.0,
#   'demgov16': 'null',
#   'otherpres16': 1557,
#   'ruralurban_cc': 1.0,
#   'cvap': 51745.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 32},
#    '4/29/20': {'deaths': 2, 'cases': 67},
#    '5/13/20': {'deaths': 2, 'cases': 120},
#    '5/27/20': {'deaths': 2, 'cases': 190},
#    '6/10/20': {'deaths': 4, 'cases': 279}}},
#  '55113': {'coordinates': [[[-91.551282, 46.157045],
#     [-91.540294, 45.637605],
#     [-90.678749, 45.638264],
#     [-90.676968, 45.981553999999996],
#     [-90.925174, 45.981055],
#     [-90.924583, 46.154616],
#     [-91.551282, 46.157045]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '55',
#   'county_fips': '113',
#   'county_name': 'Sawyer',
#   'land_area': 3257216619,
#   'water_area': 239883874,
#   'state': 'WI',
#   'population': 16558,
#   'trump16': 5185,
#   'age65andolder_pct': 23.3179218883076,
#   'lesscollege_pct': 77.8659393338292,
#   'foreignborn_pct': 1.5026158900109499,
#   'hispanic_pct': 2.26913249787079,
#   'clf_unemploy_pct': 7.6651867328284204,
#   'black_pct': 0.663097700450176,
#   'repgov16': 'null',
#   'rural_pct': 84.200036238449,
#   'age29andunder_pct': 30.800584012653605,
#   'lesshs_pct': 8.90156211257129,
#   'clinton16': 3504,
#   'female_pct': 49.3064849738411,
#   'white_pct': 77.3025915561504,
#   'median_hh_inc': 41869.0,
#   'demgov16': 'null',
#   'otherpres16': 432,
#   'ruralurban_cc': 7.0,
#   'cvap': 13055.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 2},
#    '4/29/20': {'deaths': 0, 'cases': 3},
#    '5/13/20': {'deaths': 0, 'cases': 4},
#    '5/27/20': {'deaths': 0, 'cases': 7},
#    '6/10/20': {'deaths': 0, 'cases': 9}}},
#  '48233': {'coordinates': [[[-101.623466, 36.055405],
#     [-101.622831, 35.624057],
#     [-101.086068, 35.625267],
#     [-101.085735, 36.055276],
#     [-101.623466, 36.055405]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '48',
#   'county_fips': '233',
#   'county_name': 'Hutchinson',
#   'land_area': 2298408152,
#   'water_area': 19507502,
#   'state': 'TX',
#   'population': 20938,
#   'trump16': 7042,
#   'age65andolder_pct': 14.842530529795198,
#   'lesscollege_pct': 84.7153552761689,
#   'foreignborn_pct': 5.114314571664679,
#   'hispanic_pct': 22.1742723349555,
#   'clf_unemploy_pct': 4.880016132284731,
#   'black_pct': 2.13938114039115,
#   'repgov16': 'null',
#   'rural_pct': 22.5643340857788,
#   'age29andunder_pct': 40.3406482416674,
#   'lesshs_pct': 15.1080661110326,
#   'clinton16': 854,
#   'female_pct': 50.1744559728216,
#   'white_pct': 71.6784500964099,
#   'median_hh_inc': 50114.0,
#   'demgov16': 'null',
#   'otherpres16': 259,
#   'ruralurban_cc': 6.0,
#   'cvap': 15505.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 3},
#    '4/29/20': {'deaths': 0, 'cases': 13},
#    '5/13/20': {'deaths': 0, 'cases': 25},
#    '5/27/20': {'deaths': 0, 'cases': 30},
#    '6/10/20': {'deaths': 0, 'cases': 44}}},
#  '55031': {'coordinates': [[[-92.2927598024283, 46.41721950288],
#     [-92.29361899999999, 46.244043],
#     [-92.2938306085787, 46.157321306496],
#     [-92.04963599999999, 46.157596999999996],
#     [-91.551282, 46.157045],
#     [-91.551936, 46.748110999999994],
#     [-91.55134153565639, 46.7574752934595],
#     [-91.574291, 46.757487999999995],
#     [-91.645502, 46.734733],
#     [-91.820027, 46.690176],
#     [-91.886963, 46.690211],
#     [-91.961889, 46.682539],
#     [-92.01529, 46.706469],
#     [-92.05081899999999, 46.710516999999996],
#     [-92.10025499999999, 46.734446],
#     [-92.143338, 46.731595999999996],
#     [-92.18309099999999, 46.695240999999996],
#     [-92.20549199999999, 46.664741],
#     [-92.292192, 46.663242],
#     [-92.292371, 46.495585],
#     [-92.2927598024283, 46.41721950288]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '55',
#   'county_fips': '031',
#   'county_name': 'Douglas',
#   'land_area': 3378102266,
#   'water_area': 454243357,
#   'state': 'WI',
#   'population': 43150,
#   'trump16': 9659,
#   'age65andolder_pct': 16.2773138084887,
#   'lesscollege_pct': 77.2224031260176,
#   'foreignborn_pct': 1.61308774739732,
#   'hispanic_pct': 1.42546619379934,
#   'clf_unemploy_pct': 6.37201380093462,
#   'black_pct': 1.1646264729436002,
#   'repgov16': 'null',
#   'rural_pct': 38.755406598881294,
#   'age29andunder_pct': 36.2384166571331,
#   'lesshs_pct': 6.427873656789321,
#   'clinton16': 11345,
#   'female_pct': 50.088090607482,
#   'white_pct': 92.0855737329825,
#   'median_hh_inc': 48190.0,
#   'demgov16': 'null',
#   'otherpres16': 1507,
#   'ruralurban_cc': 2.0,
#   'cvap': 34415.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 7},
#    '4/29/20': {'deaths': 0, 'cases': 9},
#    '5/13/20': {'deaths': 0, 'cases': 11},
#    '5/27/20': {'deaths': 0, 'cases': 19},
#    '6/10/20': {'deaths': 0, 'cases': 20}}},
#  '48095': {'coordinates': [[[-100.111234, 31.580267],
#     [-100.115216, 31.087994],
#     [-99.603223, 31.087296],
#     [-99.60185, 31.49195],
#     [-99.62491999999999, 31.467442],
#     [-99.72169799999999, 31.576759],
#     [-100.111234, 31.580267]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '48',
#   'county_fips': '095',
#   'county_name': 'Concho',
#   'land_area': 2547914009,
#   'water_area': 25740025,
#   'state': 'TX',
#   'population': 2726,
#   'trump16': 885,
#   'age65andolder_pct': 15.910188314823802,
#   'lesscollege_pct': 88.5098165432893,
#   'foreignborn_pct': 33.1723804925157,
#   'hispanic_pct': 55.45630130371801,
#   'clf_unemploy_pct': 1.9498607242339798,
#   'black_pct': 0.700144857556736,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 31.0478029937228,
#   'lesshs_pct': 38.558094625040205,
#   'clinton16': 148,
#   'female_pct': 31.1685176243361,
#   'white_pct': 42.757122163206205,
#   'median_hh_inc': 48516.0,
#   'demgov16': 'null',
#   'otherpres16': 35,
#   'ruralurban_cc': 8.0,
#   'cvap': 2255.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 1},
#    '5/13/20': {'deaths': 0, 'cases': 1},
#    '5/27/20': {'deaths': 0, 'cases': 1},
#    '6/10/20': {'deaths': 0, 'cases': 1}}},
#  '51065': {'coordinates': [[[-78.491345, 37.796956],
#     [-78.46414899999999, 37.760200000000005],
#     [-78.23974799999999, 37.690495],
#     [-78.18099, 37.744959],
#     [-78.159326, 37.748528],
#     [-78.147714, 37.773949],
#     [-78.06248099999999, 37.904685],
#     [-78.205125, 37.957339999999995],
#     [-78.30676299999999, 38.006474],
#     [-78.491345, 37.796956]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '51',
#   'county_fips': '065',
#   'county_name': 'Fluvanna',
#   'land_area': 743630414,
#   'water_area': 10747025,
#   'state': 'VA',
#   'population': 27270,
#   'trump16': 7025,
#   'age65andolder_pct': 18.4903632035629,
#   'lesscollege_pct': 68.9945945945946,
#   'foreignborn_pct': 2.84496659755817,
#   'hispanic_pct': 3.2941718498041896,
#   'clf_unemploy_pct': 5.3372573973910304,
#   'black_pct': 13.833218152499402,
#   'repgov16': 'null',
#   'rural_pct': 62.9130824023977,
#   'age29andunder_pct': 33.9245949474008,
#   'lesshs_pct': 10.6594594594595,
#   'clinton16': 5760,
#   'female_pct': 54.5957152729786,
#   'white_pct': 78.7184212547032,
#   'median_hh_inc': 66425.0,
#   'demgov16': 'null',
#   'otherpres16': 812,
#   'ruralurban_cc': 3.0,
#   'cvap': 20200.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 62},
#    '4/29/20': {'deaths': 5, 'cases': 73},
#    '5/13/20': {'deaths': 6, 'cases': 79},
#    '5/27/20': {'deaths': 6, 'cases': 87},
#    '6/10/20': {'deaths': 6, 'cases': 98}}},
#  '55041': {'coordinates': [[[-88.9327684510096, 46.072107163775996],
#     [-88.933222, 45.982276],
#     [-89.047795, 45.982344999999995],
#     [-89.047601, 45.895354999999995],
#     [-89.04648999999999, 45.464439],
#     [-88.923062, 45.465137],
#     [-88.926025, 45.378637],
#     [-88.677996, 45.378682999999995],
#     [-88.428102, 45.37701],
#     [-88.425302, 45.722426],
#     [-88.675821, 45.7229],
#     [-88.68323220849939, 46.0144656703203],
#     [-88.739994, 46.027308],
#     [-88.811948, 46.021609],
#     [-88.9327684510096, 46.072107163775996]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '55',
#   'county_fips': '041',
#   'county_name': 'Forest',
#   'land_area': 2626878508,
#   'water_area': 83594186,
#   'state': 'WI',
#   'population': 9004,
#   'trump16': 2788,
#   'age65andolder_pct': 22.0026350461133,
#   'lesscollege_pct': 85.91657688163771,
#   'foreignborn_pct': 1.10891523935002,
#   'hispanic_pct': 2.03118137900747,
#   'clf_unemploy_pct': 9.7536450477627,
#   'black_pct': 1.27360562143171,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 33.596837944664,
#   'lesshs_pct': 13.529321225180901,
#   'clinton16': 1584,
#   'female_pct': 49.615722441809396,
#   'white_pct': 80.18225735617041,
#   'median_hh_inc': 41378.0,
#   'demgov16': 'null',
#   'otherpres16': 168,
#   'ruralurban_cc': 9.0,
#   'cvap': 7200.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 0},
#    '4/29/20': {'deaths': 0, 'cases': 0},
#    '5/13/20': {'deaths': 0, 'cases': 5},
#    '5/27/20': {'deaths': 1, 'cases': 24},
#    '6/10/20': {'deaths': 2, 'cases': 34}}},
#  '26121': {'coordinates': [[[-86.46351688668109, 43.472329699506695],
#     [-86.448743, 43.432013],
#     [-86.407832, 43.338436],
#     [-86.316259, 43.195114],
#     [-86.27392827867139, 43.1183679687078],
#     [-85.90743499999999, 43.118911],
#     [-85.908388, 43.20592],
#     [-85.790662, 43.205166999999996],
#     [-85.790448, 43.293003],
#     [-86.03895299999999, 43.293518999999996],
#     [-86.039491, 43.467447],
#     [-86.46351688668109, 43.472329699506695]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '26',
#   'county_fips': '121',
#   'county_name': 'Muskegon',
#   'land_area': 1305064357,
#   'water_area': 2476380060,
#   'state': 'MI',
#   'population': 173566,
#   'trump16': 36127,
#   'age65andolder_pct': 15.121290982178099,
#   'lesscollege_pct': 81.97757654161279,
#   'foreignborn_pct': 1.5440202616353402,
#   'hispanic_pct': 5.328554499616611,
#   'clf_unemploy_pct': 10.440605833020399,
#   'black_pct': 13.562167437321401,
#   'repgov16': 'null',
#   'rural_pct': 23.314632843171395,
#   'age29andunder_pct': 38.94207309989079,
#   'lesshs_pct': 10.7943078913325,
#   'clinton16': 37304,
#   'female_pct': 50.321816111717794,
#   'white_pct': 76.7078327950368,
#   'median_hh_inc': 43920.0,
#   'demgov16': 'null',
#   'otherpres16': 4657,
#   'ruralurban_cc': 3.0,
#   'cvap': 129975.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 5, 'cases': 93},
#    '4/29/20': {'deaths': 16, 'cases': 262},
#    '5/13/20': {'deaths': 20, 'cases': 406},
#    '5/27/20': {'deaths': 33, 'cases': 606},
#    '6/10/20': {'deaths': 40, 'cases': 726}}},
#  '27005': {'coordinates': [[[-96.194671, 47.151149],
#     [-96.17410799999999, 46.977374999999995],
#     [-96.174587, 46.717853999999996],
#     [-95.247999, 46.716255],
#     [-95.16371, 46.717639999999996],
#     [-95.16301, 46.804719999999996],
#     [-95.16917199999999, 47.152515],
#     [-95.551186, 47.151453],
#     [-96.06706899999999, 47.151813],
#     [-96.194671, 47.151149]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '27',
#   'county_fips': '005',
#   'county_name': 'Becker',
#   'land_area': 3406054658,
#   'water_area': 336952350,
#   'state': 'MN',
#   'population': 34423,
#   'trump16': 10880,
#   'age65andolder_pct': 19.1460674157303,
#   'lesscollege_pct': 76.27326472520251,
#   'foreignborn_pct': 1.7348314606741597,
#   'hispanic_pct': 1.75880149812734,
#   'clf_unemploy_pct': 3.72248404223588,
#   'black_pct': 0.45543071161048704,
#   'repgov16': 'null',
#   'rural_pct': 75.47071129707109,
#   'age29andunder_pct': 36.686142322097396,
#   'lesshs_pct': 7.576089336544781,
#   'clinton16': 5208,
#   'female_pct': 49.9835205992509,
#   'white_pct': 86.7595505617978,
#   'median_hh_inc': 54115.0,
#   'demgov16': 'null',
#   'otherpres16': 1134,
#   'ruralurban_cc': 6.0,
#   'cvap': 24855.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 2},
#    '5/13/20': {'deaths': 0, 'cases': 28},
#    '5/27/20': {'deaths': 0, 'cases': 36},
#    '6/10/20': {'deaths': 0, 'cases': 45}}},
#  '40077': {'coordinates': [[[-95.349233, 35.058513999999995],
#     [-95.349437, 35.029299],
#     [-95.50765799999999, 35.029196999999996],
#     [-95.51451399999999, 34.681142],
#     [-95.05961599999999, 34.680735999999996],
#     [-95.059512, 34.855019],
#     [-94.99781, 34.855078],
#     [-94.99812, 34.942157],
#     [-94.927668, 34.942212],
#     [-94.927863, 35.058279],
#     [-95.349233, 35.058513999999995]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '40',
#   'county_fips': '077',
#   'county_name': 'Latimer',
#   'land_area': 1870096895,
#   'water_area': 18296988,
#   'state': 'OK',
#   'population': 10073,
#   'trump16': 3100,
#   'age65andolder_pct': 19.3648407403927,
#   'lesscollege_pct': 84.1334647332113,
#   'foreignborn_pct': 1.2684393498073898,
#   'hispanic_pct': 3.2791506154279797,
#   'clf_unemploy_pct': 8.64890135577373,
#   'black_pct': 1.2026684205581102,
#   'repgov16': 'null',
#   'rural_pct': 73.2920925228618,
#   'age29andunder_pct': 38.8424316452128,
#   'lesshs_pct': 15.852456708433099,
#   'clinton16': 797,
#   'female_pct': 49.328196936953894,
#   'white_pct': 66.5977637884055,
#   'median_hh_inc': 39701.0,
#   'demgov16': 'null',
#   'otherpres16': 159,
#   'ruralurban_cc': 7.0,
#   'cvap': 8195.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 4},
#    '4/29/20': {'deaths': 1, 'cases': 5},
#    '5/13/20': {'deaths': 1, 'cases': 5},
#    '5/27/20': {'deaths': 1, 'cases': 5},
#    '6/10/20': {'deaths': 1, 'cases': 5}}},
#  '22073': {'coordinates': [[[-92.41534999999999, 32.495486],
#     [-92.415418, 32.407812],
#     [-92.31182899999999, 32.320755],
#     [-92.31185099999999, 32.277440999999996],
#     [-92.106115, 32.258552],
#     [-92.034397, 32.277068],
#     [-91.994208, 32.401094],
#     [-91.913057, 32.505902],
#     [-91.94341899999999, 32.587119],
#     [-91.91116799999999, 32.661139],
#     [-92.065179, 32.723003],
#     [-92.224265, 32.590094],
#     [-92.415071, 32.582845],
#     [-92.41534999999999, 32.495486]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '22',
#   'county_fips': '073',
#   'county_name': 'Ouachita',
#   'land_area': 1580920629,
#   'water_area': 55305574,
#   'state': 'LA',
#   'population': 153279,
#   'trump16': 41734,
#   'age65andolder_pct': 13.3889180168544,
#   'lesscollege_pct': 75.81829658053721,
#   'foreignborn_pct': 1.6291768436936498,
#   'hispanic_pct': 2.1004104911827497,
#   'clf_unemploy_pct': 7.84460109399452,
#   'black_pct': 37.4461310246934,
#   'repgov16': 'null',
#   'rural_pct': 24.191386937288605,
#   'age29andunder_pct': 43.4417319914577,
#   'lesshs_pct': 14.970293855386698,
#   'clinton16': 24428,
#   'female_pct': 52.066522589802894,
#   'white_pct': 58.516093556183606,
#   'median_hh_inc': 38974.0,
#   'demgov16': 'null',
#   'otherpres16': 1855,
#   'ruralurban_cc': 3.0,
#   'cvap': 115005.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 8, 'cases': 411},
#    '4/29/20': {'deaths': 16, 'cases': 671},
#    '5/13/20': {'deaths': 31, 'cases': 861},
#    '5/27/20': {'deaths': 37, 'cases': 1150},
#    '6/10/20': {'deaths': 57, 'cases': 1592}}},
#  '01023': {'coordinates': [[[-88.4686624840513, 31.893855711615597],
#     [-88.46866899999999, 31.790722],
#     [-88.4636253046849, 31.697942371350198],
#     [-88.08828799999999, 31.699302999999997],
#     [-88.18038399999999, 31.814546],
#     [-88.121414, 31.950256],
#     [-88.07348999999999, 31.990181999999997],
#     [-88.113584, 32.00624],
#     [-88.007077, 32.185313],
#     [-88.019145, 32.28524],
#     [-87.930661, 32.310573999999995],
#     [-88.4213122213943, 32.308679123011295],
#     [-88.42827799999999, 32.250143],
#     [-88.4311453634628, 32.227636234688894],
#     [-88.45338776310929, 32.053049205419704],
#     [-88.46866, 31.933173],
#     [-88.4686624840513, 31.893855711615597]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '01',
#   'county_fips': '023',
#   'county_name': 'Choctaw',
#   'land_area': 2365869835,
#   'water_area': 19144469,
#   'state': 'AL',
#   'population': 12589,
#   'trump16': 4106,
#   'age65andolder_pct': 20.749604876947398,
#   'lesscollege_pct': 88.0397967823878,
#   'foreignborn_pct': 0.165575374426131,
#   'hispanic_pct': 0.5569353503424399,
#   'clf_unemploy_pct': 13.6428137036286,
#   'black_pct': 42.2292466320464,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 33.4010687137804,
#   'lesshs_pct': 21.14733276884,
#   'clinton16': 3109,
#   'female_pct': 52.2164521712953,
#   'white_pct': 56.205313464288395,
#   'median_hh_inc': 32622.0,
# ...
#   'hispanic_pct': 3.9907609393045003,
#   'clf_unemploy_pct': 5.3109713487072,
#   'black_pct': 0.8982420120621071,
#   'repgov16': 'null',
#   'rural_pct': 58.891013384321205,
#   'age29andunder_pct': 34.8261260105223,
#   'lesshs_pct': 7.519764662621809,
#   'clinton16': 602,
#   'female_pct': 50.545361221609106,
#   'white_pct': 93.08353650712179,
#   'median_hh_inc': 50464.0,
#   'demgov16': 'null',
#   'otherpres16': 260,
#   'ruralurban_cc': 3.0,
#   'cvap': 5890.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 5},
#    '4/29/20': {'deaths': 0, 'cases': 12},
#    '5/13/20': {'deaths': 0, 'cases': 26},
#    '5/27/20': {'deaths': 0, 'cases': 32},
#    '6/10/20': {'deaths': 0, 'cases': 36}}},
#  '21211': {'coordinates': [[[-85.468206, 38.285309],
#     [-85.404899, 38.263729999999995],
#     [-85.424054, 38.147438],
#     [-85.232406, 38.089431],
#     [-85.196117, 38.074822],
#     [-85.101646, 38.03727],
#     [-85.047783, 38.072341],
#     [-85.02371099999999, 38.129052],
#     [-84.998898, 38.274978999999995],
#     [-84.956959, 38.332271],
#     [-84.99766699999999, 38.335586],
#     [-85.283082, 38.358053999999996],
#     [-85.32445299999999, 38.310112],
#     [-85.468206, 38.285309]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '21',
#   'county_fips': '211',
#   'county_name': 'Shelby',
#   'land_area': 983573702,
#   'water_area': 15290028,
#   'state': 'KY',
#   'population': 49024,
#   'trump16': 13196,
#   'age65andolder_pct': 13.714501745724599,
#   'lesscollege_pct': 76.1511099400567,
#   'foreignborn_pct': 6.607067404985879,
#   'hispanic_pct': 8.850935130206599,
#   'clf_unemploy_pct': 4.886403052376,
#   'black_pct': 6.99179398225365,
#   'repgov16': 'null',
#   'rural_pct': 47.007653182488,
#   'age29andunder_pct': 38.5327017590678,
#   'lesshs_pct': 14.1953757986957,
#   'clinton16': 6276,
#   'female_pct': 51.69124024284471,
#   'white_pct': 80.46567482820741,
#   'median_hh_inc': 61737.0,
#   'demgov16': 'null',
#   'otherpres16': 1108,
#   'ruralurban_cc': 1.0,
#   'cvap': 31920.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 21},
#    '4/29/20': {'deaths': 3, 'cases': 28},
#    '5/13/20': {'deaths': 3, 'cases': 54},
#    '5/27/20': {'deaths': 4, 'cases': 138},
#    '6/10/20': {'deaths': 6, 'cases': 233}}},
#  '54051': {'coordinates': [[[-80.8234381047859, 39.8500320873964],
#     [-80.824276, 39.847159],
#     [-80.824969, 39.801092],
#     [-80.869933, 39.763555],
#     [-80.8355216930075, 39.7192518022001],
#     [-80.519342, 39.721402999999995],
#     [-80.5191607943145, 39.962200052521894],
#     [-80.51912, 40.01641],
#     [-80.7382184399836, 40.0335432260784],
#     [-80.74012599999999, 39.970793],
#     [-80.764479, 39.95025],
#     [-80.803394, 39.918762],
#     [-80.8234381047859, 39.8500320873964]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '54',
#   'county_fips': '051',
#   'county_name': 'Marshall',
#   'land_area': 791063494,
#   'water_area': 17411506,
#   'state': 'WV',
#   'population': 30531,
#   'trump16': 9666,
#   'age65andolder_pct': 19.327470894228398,
#   'lesscollege_pct': 83.86889460154241,
#   'foreignborn_pct': 0.9320039633391128,
#   'hispanic_pct': 0.9412930393856821,
#   'clf_unemploy_pct': 5.98727005665524,
#   'black_pct': 0.9660639088431999,
#   'repgov16': 5696.0,
#   'rural_pct': 48.9926601625034,
#   'age29andunder_pct': 33.0876888778796,
#   'lesshs_pct': 10.822622107969199,
#   'clinton16': 2918,
#   'female_pct': 50.75551151845429,
#   'white_pct': 96.86338865494179,
#   'median_hh_inc': 44464.0,
#   'demgov16': 6491.0,
#   'otherpres16': 632,
#   'ruralurban_cc': 3.0,
#   'cvap': 25715.0,
#   'othergov16': 938.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 7},
#    '4/29/20': {'deaths': 0, 'cases': 11},
#    '5/13/20': {'deaths': 0, 'cases': 23},
#    '5/27/20': {'deaths': 0, 'cases': 27},
#    '6/10/20': {'deaths': 0, 'cases': 33}}},
#  '54031': {'coordinates': [[[-79.13429599999999, 38.81334],
#     [-79.057253, 38.761413],
#     [-79.02305299999999, 38.798612999999996],
#     [-78.999014, 38.840074],
#     [-78.869276, 38.762991],
#     [-78.821167, 38.830982],
#     [-78.772793, 38.893741999999996],
#     [-78.681617, 38.92584],
#     [-78.620453, 38.982600999999995],
#     [-78.561711, 39.009007],
#     [-78.53226618655701, 39.0527645240444],
#     [-78.508132, 39.088629999999995],
#     [-78.56128199999999, 39.131443999999995],
#     [-78.623555, 39.118508999999996],
#     [-78.97989799999999, 39.237624],
#     [-79.089655, 39.038208],
#     [-79.046853, 38.927209999999995],
#     [-79.13429599999999, 38.81334]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '54',
#   'county_fips': '031',
#   'county_name': 'Hardy',
#   'land_area': 1508194692,
#   'water_area': 5617193,
#   'state': 'WV',
#   'population': 13776,
#   'trump16': 4274,
#   'age65andolder_pct': 19.5739492181896,
#   'lesscollege_pct': 85.3406744666208,
#   'foreignborn_pct': 3.8158083488739103,
#   'hispanic_pct': 4.13140152058528,
#   'clf_unemploy_pct': 6.917086578103531,
#   'black_pct': 4.16009180892268,
#   'repgov16': 3015.0,
#   'rural_pct': 80.52049910873441,
#   'age29andunder_pct': 32.6423755558743,
#   'lesshs_pct': 19.6834136269787,
#   'clinton16': 1155,
#   'female_pct': 50.2582125950366,
#   'white_pct': 90.8980060249606,
#   'median_hh_inc': 39840.0,
#   'demgov16': 2237.0,
#   'otherpres16': 214,
#   'ruralurban_cc': 6.0,
#   'cvap': 10890.0,
#   'othergov16': 310.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 3},
#    '4/29/20': {'deaths': 0, 'cases': 5},
#    '5/13/20': {'deaths': 0, 'cases': 23},
#    '5/27/20': {'deaths': 0, 'cases': 38},
#    '6/10/20': {'deaths': 0, 'cases': 40}}},
#  '12107': {'coordinates': [[[-82.05562499999999, 29.718232],
#     [-82.050955, 29.702568999999997],
#     [-82.055899, 29.471231999999997],
#     [-82.004385, 29.501714999999997],
#     [-81.843009, 29.521003999999998],
#     [-81.77620499999999, 29.487447999999997],
#     [-81.741422, 29.371049],
#     [-81.680903, 29.32443],
#     [-81.445886, 29.380142],
#     [-81.43399199999999, 29.398552],
#     [-81.47689299999999, 29.396552],
#     [-81.520596, 29.500249],
#     [-81.52365999999999, 29.622432],
#     [-81.524804, 29.721586],
#     [-81.52523, 29.759497],
#     [-81.58120699999999, 29.840176],
#     [-81.81233, 29.836479999999998],
#     [-81.90926, 29.79356],
#     [-81.939427, 29.747497],
#     [-82.049244, 29.71867],
#     [-82.05562499999999, 29.718232]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '12',
#   'county_fips': '107',
#   'county_name': 'Putnam',
#   'land_area': 1885167077,
#   'water_area': 256548277,
#   'state': 'FL',
#   'population': 74521,
#   'trump16': 22138,
#   'age65andolder_pct': 21.1163974330604,
#   'lesscollege_pct': 87.3206258220294,
#   'foreignborn_pct': 4.22106660765656,
#   'hispanic_pct': 9.54442354503209,
#   'clf_unemploy_pct': 11.4257256687536,
#   'black_pct': 16.3628568267316,
#   'repgov16': 'null',
#   'rural_pct': 56.162928298639095,
#   'age29andunder_pct': 35.0146603230803,
#   'lesshs_pct': 21.589682181346998,
#   'clinton16': 10094,
#   'female_pct': 50.6099247621155,
#   'white_pct': 71.8673932285904,
#   'median_hh_inc': 33003.0,
#   'demgov16': 'null',
#   'otherpres16': 885,
#   'ruralurban_cc': 4.0,
#   'cvap': 54535.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 1, 'cases': 46},
#    '4/29/20': {'deaths': 1, 'cases': 103},
#    '5/13/20': {'deaths': 2, 'cases': 127},
#    '5/27/20': {'deaths': 4, 'cases': 144},
#    '6/10/20': {'deaths': 6, 'cases': 176}}},
#  '20051': {'coordinates': [[[-99.591776, 39.132357],
#     [-99.598323, 38.696514],
#     [-99.585087, 38.696537],
#     [-99.042626, 38.696807],
#     [-99.03750000000001, 39.133120999999996],
#     [-99.047687, 39.133013999999996],
#     [-99.591776, 39.132357]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '20',
#   'county_fips': '051',
#   'county_name': 'Ellis',
#   'land_area': 2330762299,
#   'water_area': 1197085,
#   'state': 'KS',
#   'population': 28553,
#   'trump16': 8466,
#   'age65andolder_pct': 14.1499035546983,
#   'lesscollege_pct': 65.8654944051153,
#   'foreignborn_pct': 3.4479195370625497,
#   'hispanic_pct': 5.48360429870488,
#   'clf_unemploy_pct': 3.3940049258124603,
#   'black_pct': 1.0712317442821702,
#   'repgov16': 'null',
#   'rural_pct': 25.558835934205,
#   'age29andunder_pct': 46.9826398456875,
#   'lesshs_pct': 6.6853162822562195,
#   'clinton16': 2742,
#   'female_pct': 49.955221824194005,
#   'white_pct': 90.48980435381651,
#   'median_hh_inc': 50140.0,
#   'demgov16': 'null',
#   'otherpres16': 739,
#   'ruralurban_cc': 5.0,
#   'cvap': 22270.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 4},
#    '4/29/20': {'deaths': 0, 'cases': 8},
#    '5/13/20': {'deaths': 0, 'cases': 9},
#    '5/27/20': {'deaths': 0, 'cases': 9},
#    '6/10/20': {'deaths': 0, 'cases': 14}}},
#  '38041': {'coordinates': [[[-102.928003, 46.630064999999995],
#     [-102.924547, 46.281518999999996],
#     [-102.497449, 46.283196],
#     [-102.497475, 46.206077],
#     [-101.997888, 46.20548],
#     [-102.046929, 46.283606],
#     [-102.051237, 46.630905999999996],
#     [-102.096585, 46.631024],
#     [-102.928003, 46.630064999999995]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '38',
#   'county_fips': '041',
#   'county_name': 'Hettinger',
#   'land_area': 2932439645,
#   'water_area': 4008872,
#   'state': 'ND',
#   'population': 2499,
#   'trump16': 1050,
#   'age65andolder_pct': 26.4115195149678,
#   'lesscollege_pct': 86.21219887237308,
#   'foreignborn_pct': 1.25047366426677,
#   'hispanic_pct': 2.76619931792346,
#   'clf_unemploy_pct': 2.52442996742671,
#   'black_pct': 0.303145130731338,
#   'repgov16': 1104.0,
#   'rural_pct': 100.0,
#   'age29andunder_pct': 31.640773020083397,
#   'lesshs_pct': 12.096360840594599,
#   'clinton16': 168,
#   'female_pct': 52.557787040545705,
#   'white_pct': 92.49715801439942,
#   'median_hh_inc': 55230.0,
#   'demgov16': 143.0,
#   'otherpres16': 78,
#   'ruralurban_cc': 9.0,
#   'cvap': 2070.0,
#   'othergov16': 40.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 0},
#    '4/29/20': {'deaths': 0, 'cases': 0},
#    '5/13/20': {'deaths': 0, 'cases': 0},
#    '5/27/20': {'deaths': 0, 'cases': 0},
#    '6/10/20': {'deaths': 0, 'cases': 0}}},
#  '46029': {'coordinates': [[[-97.494254, 45.151630999999995],
#     [-97.491346, 44.804035],
#     [-96.88457, 44.804435999999995],
#     [-96.882345, 44.97687],
#     [-96.88394799999999, 45.150224],
#     [-97.226281, 45.151826],
#     [-97.249127, 45.15117],
#     [-97.494254, 45.151630999999995]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '46',
#   'county_fips': '029',
#   'county_name': 'Codington',
#   'land_area': 1780837054,
#   'water_area': 76608850,
#   'state': 'SD',
#   'population': 28009,
#   'trump16': 7764,
#   'age65andolder_pct': 15.4916445528222,
#   'lesscollege_pct': 79.0610025305551,
#   'foreignborn_pct': 1.31607258122355,
#   'hispanic_pct': 2.0655526070429597,
#   'clf_unemploy_pct': 2.84932900845895,
#   'black_pct': 0.247435989385355,
#   'repgov16': 'null',
#   'rural_pct': 22.462996290447002,
#   'age29andunder_pct': 39.8336082622104,
#   'lesshs_pct': 8.1462337802186,
#   'clinton16': 3174,
#   'female_pct': 49.62346697267451,
#   'white_pct': 93.1614430180019,
#   'median_hh_inc': 50133.0,
#   'demgov16': 'null',
#   'otherpres16': 731,
#   'ruralurban_cc': 5.0,
#   'cvap': 20915.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 13},
#    '4/29/20': {'deaths': 0, 'cases': 14},
#    '5/13/20': {'deaths': 0, 'cases': 16},
#    '5/27/20': {'deaths': 0, 'cases': 34},
#    '6/10/20': {'deaths': 0, 'cases': 43}}},
#  '47037': {'coordinates': [[[-86.91323299999999, 36.382621],
#     [-86.90625399999999, 36.366217999999996],
#     [-86.963358, 36.267004],
#     [-87.04136199999999, 36.041312],
#     [-87.053722, 36.045581999999996],
#     [-87.03922299999999, 35.989286],
#     [-86.928861, 36.052942],
#     [-86.790875, 36.036715],
#     [-86.618892, 35.968224],
#     [-86.54688399999999, 36.087817],
#     [-86.51558899999999, 36.100609999999996],
#     [-86.556865, 36.13496],
#     [-86.594286, 36.245104999999995],
#     [-86.639095, 36.255105],
#     [-86.754795, 36.405496],
#     [-86.825053, 36.349817],
#     [-86.91323299999999, 36.382621]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '47',
#   'county_fips': '037',
#   'county_name': 'Davidson',
#   'land_area': 1304032668,
#   'water_area': 56590440,
#   'state': 'TN',
#   'population': 694144,
#   'trump16': 84550,
#   'age65andolder_pct': 11.045015234658699,
#   'lesscollege_pct': 61.79705269091129,
#   'foreignborn_pct': 12.190422003788099,
#   'hispanic_pct': 9.95096461217126,
#   'clf_unemploy_pct': 6.218227814393179,
#   'black_pct': 27.4635603434723,
#   'repgov16': 'null',
#   'rural_pct': 3.4119432374685,
#   'age29andunder_pct': 42.1084468134484,
#   'lesshs_pct': 12.5039356902705,
#   'clinton16': 148864,
#   'female_pct': 51.7815192735276,
#   'white_pct': 56.5821960367429,
#   'median_hh_inc': 50484.0,
#   'demgov16': 'null',
#   'otherpres16': 15654,
#   'ruralurban_cc': 1.0,
#   'cvap': 475915.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 19, 'cases': 1283},
#    '4/29/20': {'deaths': 25, 'cases': 2454},
#    '5/13/20': {'deaths': 37, 'cases': 3623},
#    '5/27/20': {'deaths': 59, 'cases': 4826},
#    '6/10/20': {'deaths': 80, 'cases': 6190}}},
#  '48275': {'coordinates': [[[-99.996434, 33.835967],
#     [-99.99098, 33.397404],
#     [-99.472444, 33.399023],
#     [-99.474498, 33.733849],
#     [-99.554906, 33.798556],
#     [-99.700705, 33.799963],
#     [-99.835143, 33.8358],
#     [-99.996434, 33.835967]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '48',
#   'county_fips': '275',
#   'county_name': 'Knox',
#   'land_area': 2203109026,
#   'water_area': 12577260,
#   'state': 'TX',
#   'population': 3664,
#   'trump16': 1078,
#   'age65andolder_pct': 20.3835040714473,
#   'lesscollege_pct': 81.6693290734824,
#   'foreignborn_pct': 7.90648804833202,
#   'hispanic_pct': 32.4402416600998,
#   'clf_unemploy_pct': 5.389980976537731,
#   'black_pct': 6.48804833201996,
#   'repgov16': 'null',
#   'rural_pct': 100.0,
#   'age29andunder_pct': 39.217231415812996,
#   'lesshs_pct': 19.888178913738,
#   'clinton16': 247,
#   'female_pct': 49.0937746256895,
#   'white_pct': 60.415024954032,
#   'median_hh_inc': 42188.0,
#   'demgov16': 'null',
#   'otherpres16': 42,
#   'ruralurban_cc': 9.0,
#   'cvap': 2635.0,
#   'othergov16': 'null',
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 1},
#    '5/13/20': {'deaths': 0, 'cases': 1},
#    '5/27/20': {'deaths': 0, 'cases': 1},
#    '6/10/20': {'deaths': 0, 'cases': 1}}},
#  '41023': {'coordinates': [[[-119.672228, 44.995117],
#     [-119.652431, 44.823299],
#     [-119.655517, 44.307044999999995],
#     [-119.657183, 43.95892],
#     [-118.816931, 43.960733],
#     [-118.81689, 44.047827999999996],
#     [-118.587125, 44.040265999999995],
#     [-118.227645, 44.039862],
#     [-118.228843, 44.21255],
#     [-118.232214, 44.256129],
#     [-118.497499, 44.255247999999995],
#     [-118.40878599999999, 44.452647999999996],
#     [-118.305778, 44.588809999999995],
#     [-118.37503699999999, 44.646102],
#     [-118.504327, 44.665271999999995],
#     [-118.51944, 44.705886],
#     [-118.380067, 44.744226999999995],
#     [-118.285439, 44.750975],
#     [-118.295659, 44.863043],
#     [-118.228244, 44.865178],
#     [-118.244662, 44.958396],
#     [-118.364214, 44.990763],
#     [-118.43610000000001, 44.962419999999995],
#     [-118.518689, 44.995877],
#     [-119.162966, 44.996241],
#     [-119.643745, 44.994596],
#     [-119.672228, 44.995117]]],
#   'geometry_type': 'Polygon',
#   'state_fips': '41',
#   'county_fips': '023',
#   'county_name': 'Grant',
#   'land_area': 11726925901,
#   'water_area': 1893807,
#   'state': 'OR',
#   'population': 7199,
#   'trump16': 3210,
#   'age65andolder_pct': 26.663899266639,
#   'lesscollege_pct': 78.27353851757421,
#   'foreignborn_pct': 2.3522900235229,
#   'hispanic_pct': 3.50076103500761,
#   'clf_unemploy_pct': 7.38654147104851,
#   'black_pct': 0.4151100041511,
#   'repgov16': 3093.0,
#   'rural_pct': 100.0,
#   'age29andunder_pct': 28.794797287947997,
#   'lesshs_pct': 10.3624112183573,
#   'clinton16': 739,
#   'female_pct': 50.076103500761,
#   'white_pct': 92.01605092016051,
#   'median_hh_inc': 40193.0,
#   'demgov16': 904.0,
#   'otherpres16': 391,
#   'ruralurban_cc': 9.0,
#   'cvap': 5830.0,
#   'othergov16': 274.0,
#   'dates': {'4/15/20': {'deaths': 0, 'cases': 1},
#    '4/29/20': {'deaths': 0, 'cases': 1},
#    '5/13/20': {'deaths': 0, 'cases': 1},
#    '5/27/20': {'deaths': 0, 'cases': 1},
#    '6/10/20': {'deaths': 0, 'cases': 1}}},
#  ...}

# %%
Constants.COUNTY_DEMOGRAPHICS = ['trump16', 'clinton16', 'otherpres16', 
                        'repgov','demgov','othergov',
                        'cvap',
                        'white_pct', 'black_pct','hispanic_pct',
                        'foreignborn_pct',
                        'female_pct',
                        'age29andunder_pct','age65andolder_pct',
                        'median_hh_inc','clf_unemploy_pct',
                        'lesshs_pct','lesscollege_pct',
                        'rural_pct','ruralurban_cc'
                       ]
